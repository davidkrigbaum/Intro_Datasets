# %% [markdown]
# <a href="https://colab.research.google.com/github/davidkrigbaum/Intro_Datasets/blob/main/intro_datasets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Introduction to Datasets**
# ### *Michaela Buchanan - Mark III Systems*

# %% [markdown]
# ---
#
# ###Introduction

# %% [markdown]
# Finding a good dataset to train a ML/DL model off of often condidered one of the hardest aspects of starting such a project. In this notebook, I will be showing you 3 different methods of importing and interacting with a dataset once you find one you want to try. First we will be using Keras, then TensorFlow, and finally we will use one we just found on the web. Finally, we will briefly go through a few Pandas functions which are useful for quickly cleaning up a dataset for use in training.

# %% [markdown]
# ---
#
# ###Keras

# %% [markdown]
# Keras comes with several commonly used datasets which can easily be imported if you are building your model in Keras. A list of datasets available in Keras can be found [here](https://keras.io/api/datasets/). If you are just looking for a dataset to start learning how to build models, I would highly recommend going this route as these datasets are well known and documented and are also going to be clean and easy to work with.

# %% [markdown]
# We need to start by importing Keras using the following commands. Notice that Keras is now part of TensorFlow so we import it from TF.

# %%
from tensorflow import keras
from keras.datasets import imdb

# %% [markdown]
# For this example we are going to import the IMDB movie review dataset. This dataset is commonly used for sentiment classification which means you are trying to train the model to classify the reviews as positive or negative. The code below shows how to import our dataset from Keras.

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 0s 0us/step

# %% [markdown]
# This loads the dataset into X and Y training and testing groups. Let's take a look at what our X and Y values look like.

# %%
print(x_train[0])
print(y_train[0])
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 22665, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 21631, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 19193, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 10311, 8, 4, 107, 117, 5952, 15, 256, 4, 31050, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 12118, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]
# 1

# %% [markdown]
# This dataset is already preprocessed which is why we get a sequence of numbers for our X instead of a written review. The numbers show the frequency of the word they represent, ie 14 is the 14th most frequent word. To find information about your dataset like this visit the Keras documentation on it. For this dataset the documentation is located [here](https://keras.io/api/datasets/imdb/). Let's use the function built into Keras to decode our x sample back to words.

# %%
# https://stackoverflow.com/questions/42821330/restore-original-text-from-keras-s-imdb-dataset

INDEX_FROM = 3

word_to_id = imdb.get_word_index()

word_to_id = {k:(v+INDEX_FROM) for k,v in word_to_id.items()}
word_to_id["<PAD>"] = 0
word_to_id["<START>"] = 1
word_to_id["<UNK>"] = 2
word_to_id["<UNUSED>"] = 3

inverted_word_index = dict((i, word) for (word, i) in word_to_id.items())
decoded_sequence = " ".join(inverted_word_index[i] for i in x_train[0])
print(decoded_sequence)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1641221/1641221 [==============================] - 0s 0us/step
# <START> this film was just brilliant casting location scenery story direction everyone's really suited the part they played and you could just imagine being there robert redford's is an amazing actor and now the same being director norman's father came from the same scottish island as myself so i loved the fact there was a real connection with this film the witty remarks throughout the film were great it was just brilliant so much that i bought the film as soon as it was released for retail and would recommend it to everyone to watch and the fly fishing was amazing really cried at the end it was so sad and you know what they say if you cry at a film it must have been good and this definitely was also congratulations to the two little boy's that played the part's of norman and paul they were just brilliant children are often left out of the praising list i think because the stars that play them all grown up are such a big profile for the whole film but these children are amazing and should be praised for what they have done don't you think the whole story was so lovely because it was true and was someone's life after all that was shared with us all

# %% [markdown]
# This is an example of the challenges of data science. If you go directly to the documentation and try the steps they describe, you end up with jibberish. I had to look online to find a solution which ended up being in this stack overflow link I put on top of the code. This goes to show that even with the more straightforward dataset solutions you shouldn't be surprised if there are some obstacles to overcome in working with it.

# %% [markdown]
# ---
#
# ###Tensorflow

# %% [markdown]
# While the datasets provided by Keras are a great resource for getting started, they are limited in actual problem-solving value. Tensorflow provides a more extensive selection of dataset that you can import in a similar manner to importing datasets from Keras. See this [link](https://www.tensorflow.org/datasets/catalog/overview#all_datasets) to view all the datasets provided by Tensorflow. We will be importing the `oxford_iiit_pet` image dataset which includes 37 different pet categories. I followed the TensorFlow documentation located [here](https://www.tensorflow.org/datasets/overview) for this section.

# %%
import tensorflow_datasets as tfds

ds = tfds.load('oxford_iiit_pet', split='train', shuffle_files=True)
# Out:
# Downloading and preparing dataset 773.52 MiB (download: 773.52 MiB, generated: 774.69 MiB, total: 1.51 GiB) to /root/tensorflow_datasets/oxford_iiit_pet/3.2.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Shuffling /root/tensorflow_datasets/oxford_iiit_pet/3.2.0.incompleteWH7HFU/oxford_iiit_pet-train.tfrecord*...:…
# Generating test examples...:   0%|          | 0/3669 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/oxford_iiit_pet/3.2.0.incompleteWH7HFU/oxford_iiit_pet-test.tfrecord*...: …
# Dataset oxford_iiit_pet downloaded and prepared to /root/tensorflow_datasets/oxford_iiit_pet/3.2.0. Subsequent calls will reuse this data.

# %% [markdown]
# Now let's grab one example from our dataset to inspect.

# %%
import matplotlib.pyplot as plt

ds = ds.take(1)

for example in ds:
  print(list(example.keys()))
  image = example["image"]
  label = example["file_name"]
  print(label)
  plt.imshow(image)
# Out:
# ['file_name', 'image', 'label', 'segmentation_mask', 'species']
# tf.Tensor(b'Sphynx_158.jpg', shape=(), dtype=string)

# %% [markdown]
# ---
#
# ###Kaggle

# %% [markdown]
# For this section I'm not going to do a live demo but instead leave you with the link to the documentation describing how to set it up [here](https://www.kaggle.com/docs/api). The API is pretty simple to set up and use in your command prompt and allows you to easily download any Kaggle dataset to your computer. Kaggle is a great resource for dataset as you get a much greater variety of choices. However, be warned that all of them are uploaded by users like you so a significant amount of cleaning and preprocessing may be required. If you have problems with the Kaggle API feel free to reach out to me and I can help or make a seperate video showing how to do it.

# %% [markdown]
# ---
#
# ###From Source

# %% [markdown]
# The final and most traditional method of finding a dataset is just doing a Google search. Many datasets are hosted by the organization that created them and is available via direct download. As an example we are going to be looking at the [Street View House Numbers (SVHN)](http://ufldl.stanford.edu/housenumbers//) dataset which is a different, more challenging take on the classic MNIST dataset. It contains Google Street View images of house numbers and the goal is to be able to find and read the house numbers in the images.

# %% [markdown]
# If you visit the website linked for this dataset, you will see a Downloads section. Let's go ahead and download the test dataset for this example as it should be a bit smaller than the training subset.

# %%
# !wget http://ufldl.stanford.edu/housenumbers/test.tar.gz
# Out:
# --2023-09-07 17:05:30--  http://ufldl.stanford.edu/housenumbers/test.tar.gz
# Resolving ufldl.stanford.edu (ufldl.stanford.edu)... 171.64.68.10
# Connecting to ufldl.stanford.edu (ufldl.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 276555967 (264M) [application/x-gzip]
# Saving to: ‘test.tar.gz’
#
# test.tar.gz         100%[===================>] 263.74M  55.8MB/s    in 6.8s
#
# 2023-09-07 17:05:37 (38.8 MB/s) - ‘test.tar.gz’ saved [276555967/276555967]

# %% [markdown]
# The next step is to unpack the images since this download comes compressed as a `.tar.gz` file.

# %%
# !tar xvzf test.tar.gz
# Out:
# Streaming output truncated to the last 5000 lines.
# test/2574.png
# test/2554.png
# test/2550.png
# test/2549.png
# test/2535.png
# test/2528.png
# test/2519.png
# test/2516.png
# test/2510.png
# test/2504.png
# test/2494.png
# test/2491.png
# test/2485.png
# test/2477.png
# test/2470.png
# test/2432.png
# test/2390.png
# test/2385.png
# test/2351.png
# test/2339.png
# test/2320.png
# test/2316.png
# test/2315.png
# test/2296.png
# test/2279.png
# test/2271.png
# test/2258.png
# test/2249.png
# test/2245.png
# test/2229.png
# test/2209.png
# test/2197.png
# test/2192.png
# test/2190.png
# test/2186.png
# test/2178.png
# test/2175.png
# test/2157.png
# test/2154.png
# test/2150.png
# test/2148.png
# test/2128.png
# test/2126.png
# test/2116.png
# test/2103.png
# test/2077.png
# test/2061.png
# test/2047.png
# test/2015.png
# test/1945.png
# test/1939.png
# test/1903.png
# test/1869.png
# test/1859.png
# test/1847.png
# test/1836.png
# test/1826.png
# test/1817.png
# test/1804.png
# test/1796.png
# test/1791.png
# test/1783.png
# test/1773.png
# test/1764.png
# test/1744.png
# test/1718.png
# test/1680.png
# test/1678.png
# test/1667.png
# test/1656.png
# test/1654.png
# test/1641.png
# test/1635.png
# test/1633.png
# test/1621.png
# test/1619.png
# test/1610.png
# test/1594.png
# test/1588.png
# test/1576.png
# test/1572.png
# test/1565.png
# test/1555.png
# test/1547.png
# test/1539.png
# test/1533.png
# test/1509.png
# test/1486.png
# test/1475.png
# test/1456.png
# test/1439.png
# test/1418.png
# test/1410.png
# test/1407.png
# test/1405.png
# test/1396.png
# test/1392.png
# test/1364.png
# test/1339.png
# test/1298.png
# test/1295.png
# test/1290.png
# test/1267.png
# test/1245.png
# test/1228.png
# test/1225.png
# test/1203.png
# test/1202.png
# test/1199.png
# test/1186.png
# test/1181.png
# test/1154.png
# test/1146.png
# test/1139.png
# test/1137.png
# test/1128.png
# test/1120.png
# test/1078.png
# test/1067.png
# test/1061.png
# test/1060.png
# test/1053.png
# test/4460.png
# test/4439.png
# test/4398.png
# test/4354.png
# test/4321.png
# test/4315.png
# test/4293.png
# test/4281.png
# test/4280.png
# test/4265.png
# test/4259.png
# test/4254.png
# test/4219.png
# test/4205.png
# test/4198.png
# test/4189.png
# test/4171.png
# test/4163.png
# test/4139.png
# test/4128.png
# test/4126.png
# test/4097.png
# test/4094.png
# test/4092.png
# test/4085.png
# test/4079.png
# test/4050.png
# test/4035.png
# test/4024.png
# test/4016.png
# test/4013.png
# test/3979.png
# test/3972.png
# test/3970.png
# test/3964.png
# test/3943.png
# test/3940.png
# test/3939.png
# test/3923.png
# test/3913.png
# test/3883.png
# test/3881.png
# test/3875.png
# test/3871.png
# test/3864.png
# test/3851.png
# test/3835.png
# test/3829.png
# test/3823.png
# test/3821.png
# test/3820.png
# test/3816.png
# test/3754.png
# test/3728.png
# test/3727.png
# test/3696.png
# test/3694.png
# test/3661.png
# test/3649.png
# test/3597.png
# test/3596.png
# test/3591.png
# test/3574.png
# test/3570.png
# test/3568.png
# test/3548.png
# test/3521.png
# test/3468.png
# test/3463.png
# test/3449.png
# test/3448.png
# test/3428.png
# test/3426.png
# test/3403.png
# test/3400.png
# test/3379.png
# test/3376.png
# test/3366.png
# test/3343.png
# test/3340.png
# test/3326.png
# test/3287.png
# test/3259.png
# test/3245.png
# test/3234.png
# test/3205.png
# test/3200.png
# test/3181.png
# test/3180.png
# test/3164.png
# test/3145.png
# test/3133.png
# test/3131.png
# test/3124.png
# test/3109.png
# test/3099.png
# test/3083.png
# test/3073.png
# test/3060.png
# test/3046.png
# test/3037.png
# test/3032.png
# test/3019.png
# test/3001.png
# test/2955.png
# test/2940.png
# test/2918.png
# test/2917.png
# test/2911.png
# test/2907.png
# test/2900.png
# test/2896.png
# test/2881.png
# test/2875.png
# test/2869.png
# test/2859.png
# test/2828.png
# test/2804.png
# test/2800.png
# test/2788.png
# test/2784.png
# test/2753.png
# test/2751.png
# test/2723.png
# test/2693.png
# test/2659.png
# test/2658.png
# test/2629.png
# test/6038.png
# test/6037.png
# test/6010.png
# test/6002.png
# test/5981.png
# test/5974.png
# test/5964.png
# test/5963.png
# test/5955.png
# test/5953.png
# test/5947.png
# test/5938.png
# test/5931.png
# test/5926.png
# test/5921.png
# test/5903.png
# test/5876.png
# test/5833.png
# test/5827.png
# test/5811.png
# test/5792.png
# test/5751.png
# test/5737.png
# test/5734.png
# test/5730.png
# test/5723.png
# test/5722.png
# test/5686.png
# test/5660.png
# test/5659.png
# test/5634.png
# test/5625.png
# test/5557.png
# test/5555.png
# test/5544.png
# test/5532.png
# test/5529.png
# test/5525.png
# test/5517.png
# test/5514.png
# test/5500.png
# test/5483.png
# test/5473.png
# test/5464.png
# test/5461.png
# test/5460.png
# test/5411.png
# test/5401.png
# test/5391.png
# test/5372.png
# test/5366.png
# test/5333.png
# test/5331.png
# test/5322.png
# test/5302.png
# test/5283.png
# test/5272.png
# test/5254.png
# test/5243.png
# test/5225.png
# test/5219.png
# test/5206.png
# test/5199.png
# test/5196.png
# test/5195.png
# test/5192.png
# test/5168.png
# test/5153.png
# test/5145.png
# test/5121.png
# test/5118.png
# test/5107.png
# test/5102.png
# test/5097.png
# test/5087.png
# test/5076.png
# test/5075.png
# test/5046.png
# test/5026.png
# test/5023.png
# test/5013.png
# test/5011.png
# test/5008.png
# test/5001.png
# test/4957.png
# test/4943.png
# test/4925.png
# test/4919.png
# test/4915.png
# test/4897.png
# test/4896.png
# test/4885.png
# test/4873.png
# test/4868.png
# test/4867.png
# test/4861.png
# test/4838.png
# test/4829.png
# test/4795.png
# test/4794.png
# test/4775.png
# test/4773.png
# test/4771.png
# test/4747.png
# test/4743.png
# test/4723.png
# test/4720.png
# test/4716.png
# test/4704.png
# test/4703.png
# test/4696.png
# test/4684.png
# test/4673.png
# test/4668.png
# test/4657.png
# test/4653.png
# test/4652.png
# test/4614.png
# test/4602.png
# test/4599.png
# test/4571.png
# test/4554.png
# test/4551.png
# test/4548.png
# test/4511.png
# test/4508.png
# test/4498.png
# test/4465.png
# test/7701.png
# test/7699.png
# test/7695.png
# test/7664.png
# test/7658.png
# test/7655.png
# test/7654.png
# test/7618.png
# test/7591.png
# test/7590.png
# test/7574.png
# test/7555.png
# test/7531.png
# test/7530.png
# test/7522.png
# test/7506.png
# test/7485.png
# test/7436.png
# test/7428.png
# test/7426.png
# test/7402.png
# test/7388.png
# test/7382.png
# test/7364.png
# test/7360.png
# test/7339.png
# test/7334.png
# test/7331.png
# test/7330.png
# test/7323.png
# test/7303.png
# test/7299.png
# test/7268.png
# test/7263.png
# test/7251.png
# test/7237.png
# test/7234.png
# test/7218.png
# test/7206.png
# test/7201.png
# test/7196.png
# test/7178.png
# test/7165.png
# test/7142.png
# test/7116.png
# test/7109.png
# test/7097.png
# test/7095.png
# test/7087.png
# test/7083.png
# test/7066.png
# test/7065.png
# test/7033.png
# test/7020.png
# test/6999.png
# test/6998.png
# test/6997.png
# test/6995.png
# test/6982.png
# test/6961.png
# test/6935.png
# test/6926.png
# test/6909.png
# test/6891.png
# test/6869.png
# test/6867.png
# test/6858.png
# test/6857.png
# test/6846.png
# test/6845.png
# test/6827.png
# test/6822.png
# test/6810.png
# test/6798.png
# test/6795.png
# test/6790.png
# test/6777.png
# test/6772.png
# test/6755.png
# test/6728.png
# test/6726.png
# test/6720.png
# test/6691.png
# test/6676.png
# test/6644.png
# test/6622.png
# test/6618.png
# test/6605.png
# test/6587.png
# test/6563.png
# test/6561.png
# test/6557.png
# test/6550.png
# test/6543.png
# test/6539.png
# test/6535.png
# test/6518.png
# test/6513.png
# test/6506.png
# test/6488.png
# test/6468.png
# test/6408.png
# test/6389.png
# test/6384.png
# test/6372.png
# test/6366.png
# test/6348.png
# test/6283.png
# test/6282.png
# test/6280.png
# test/6272.png
# test/6269.png
# test/6252.png
# test/6230.png
# test/6227.png
# test/6196.png
# test/6190.png
# test/6180.png
# test/6163.png
# test/6156.png
# test/6140.png
# test/6117.png
# test/6103.png
# test/6092.png
# test/6059.png
# test/6052.png
# test/6042.png
# test/6040.png
# test/9456.png
# test/9420.png
# test/9391.png
# test/9380.png
# test/9362.png
# test/9351.png
# test/9348.png
# test/9337.png
# test/9284.png
# test/9277.png
# test/9276.png
# test/9274.png
# test/9260.png
# test/9256.png
# test/9255.png
# test/9204.png
# test/9195.png
# test/9193.png
# test/9189.png
# test/9163.png
# test/9140.png
# test/9116.png
# test/9084.png
# test/9083.png
# test/9070.png
# test/9062.png
# test/9054.png
# test/9015.png
# test/9014.png
# test/9010.png
# test/9005.png
# test/8976.png
# test/8969.png
# test/8968.png
# test/8957.png
# test/8932.png
# test/8902.png
# test/8895.png
# test/8885.png
# test/8865.png
# test/8863.png
# test/8858.png
# test/8829.png
# test/8799.png
# test/8772.png
# test/8754.png
# test/8738.png
# test/8728.png
# test/8720.png
# test/8709.png
# test/8682.png
# test/8673.png
# test/8665.png
# test/8651.png
# test/8629.png
# test/8599.png
# test/8595.png
# test/8577.png
# test/8530.png
# test/8528.png
# test/8518.png
# test/8481.png
# test/8464.png
# test/8448.png
# test/8434.png
# test/8422.png
# test/8408.png
# test/8407.png
# test/8395.png
# test/8377.png
# test/8367.png
# test/8364.png
# test/8358.png
# test/8355.png
# test/8346.png
# test/8330.png
# test/8308.png
# test/8291.png
# test/8287.png
# test/8276.png
# test/8266.png
# test/8260.png
# test/8250.png
# test/8239.png
# test/8225.png
# test/8222.png
# test/8211.png
# test/8183.png
# test/8157.png
# test/8154.png
# test/8149.png
# test/8143.png
# test/8131.png
# test/8126.png
# test/8125.png
# test/8118.png
# test/8114.png
# test/8097.png
# test/8095.png
# test/8085.png
# test/8063.png
# test/8020.png
# test/8019.png
# test/8014.png
# test/8000.png
# test/7996.png
# test/7991.png
# test/7940.png
# test/7921.png
# test/7915.png
# test/7907.png
# test/7902.png
# test/7896.png
# test/7892.png
# test/7887.png
# test/7873.png
# test/7865.png
# test/7860.png
# test/7847.png
# test/7846.png
# test/7818.png
# test/7799.png
# test/7783.png
# test/7769.png
# test/7747.png
# test/7730.png
# test/7722.png
# test/7715.png
# test/10885.png
# test/10838.png
# test/10830.png
# test/10824.png
# test/10804.png
# test/10793.png
# test/10774.png
# test/10767.png
# test/10763.png
# test/10757.png
# test/10741.png
# test/10735.png
# test/10715.png
# test/10711.png
# test/10710.png
# test/10688.png
# test/10670.png
# test/10659.png
# test/10650.png
# test/10648.png
# test/10645.png
# test/10617.png
# test/10616.png
# test/10614.png
# test/10613.png
# test/10596.png
# test/10594.png
# test/10589.png
# test/10571.png
# test/10560.png
# test/10551.png
# test/10516.png
# test/10508.png
# test/10505.png
# test/10496.png
# test/10495.png
# test/10492.png
# test/10479.png
# test/10449.png
# test/10435.png
# test/10428.png
# test/10420.png
# test/10402.png
# test/10397.png
# test/10377.png
# test/10376.png
# test/10363.png
# test/10361.png
# test/10354.png
# test/10348.png
# test/10338.png
# test/10334.png
# test/10332.png
# test/10331.png
# test/10317.png
# test/10314.png
# test/10310.png
# test/10308.png
# test/10306.png
# test/10299.png
# test/10289.png
# test/10276.png
# test/10274.png
# test/10258.png
# test/10235.png
# test/10232.png
# test/10227.png
# test/10219.png
# test/10188.png
# test/10177.png
# test/10174.png
# test/10166.png
# test/10157.png
# test/10134.png
# test/10133.png
# test/10115.png
# test/10086.png
# test/10081.png
# test/10061.png
# test/10050.png
# test/10046.png
# test/10043.png
# test/10032.png
# test/10023.png
# test/9984.png
# test/9923.png
# test/9882.png
# test/9880.png
# test/9870.png
# test/9859.png
# test/9832.png
# test/9821.png
# test/9817.png
# test/9795.png
# test/9790.png
# test/9781.png
# test/9777.png
# test/9731.png
# test/9713.png
# test/9711.png
# test/9705.png
# test/9702.png
# test/9699.png
# test/9686.png
# test/9673.png
# test/9671.png
# test/9670.png
# test/9669.png
# test/9659.png
# test/9653.png
# test/9651.png
# test/9646.png
# test/9645.png
# test/9630.png
# test/9621.png
# test/9615.png
# test/9608.png
# test/9598.png
# test/9595.png
# test/9585.png
# test/9562.png
# test/9557.png
# test/9542.png
# test/9495.png
# test/9490.png
# test/9476.png
# test/9461.png
# test/9457.png
# test/12584.png
# test/12562.png
# test/12538.png
# test/12529.png
# test/12515.png
# test/12498.png
# test/12495.png
# test/12494.png
# test/12442.png
# test/12437.png
# test/12425.png
# test/12395.png
# test/12391.png
# test/12388.png
# test/12363.png
# test/12356.png
# test/12317.png
# test/12292.png
# test/12264.png
# test/12260.png
# test/12256.png
# test/12241.png
# test/12234.png
# test/12213.png
# test/12212.png
# test/12194.png
# test/12187.png
# test/12182.png
# test/12176.png
# test/12170.png
# test/12165.png
# test/12157.png
# test/12137.png
# test/12131.png
# test/12123.png
# test/12118.png
# test/12102.png
# test/12094.png
# test/12092.png
# test/12080.png
# test/12075.png
# test/12062.png
# test/12061.png
# test/12052.png
# test/12050.png
# test/12038.png
# test/12029.png
# test/12022.png
# test/12005.png
# test/12004.png
# test/12003.png
# test/11998.png
# test/11965.png
# test/11954.png
# test/11934.png
# test/11930.png
# test/11898.png
# test/11894.png
# test/11893.png
# test/11885.png
# test/11880.png
# test/11851.png
# test/11844.png
# test/11826.png
# test/11814.png
# test/11809.png
# test/11803.png
# test/11776.png
# test/11755.png
# test/11734.png
# test/11706.png
# test/11691.png
# test/11685.png
# test/11677.png
# test/11671.png
# test/11643.png
# test/11623.png
# test/11619.png
# test/11600.png
# test/11599.png
# test/11595.png
# test/11586.png
# test/11572.png
# test/11527.png
# test/11498.png
# test/11477.png
# test/11455.png
# test/11452.png
# test/11431.png
# test/11405.png
# test/11388.png
# test/11371.png
# test/11368.png
# test/11332.png
# test/11327.png
# test/11324.png
# test/11305.png
# test/11297.png
# test/11265.png
# test/11261.png
# test/11226.png
# test/11223.png
# test/11221.png
# test/11191.png
# test/11172.png
# test/11140.png
# test/11138.png
# test/11114.png
# test/11111.png
# test/11088.png
# test/11084.png
# test/11066.png
# test/11045.png
# test/11042.png
# test/11040.png
# test/11012.png
# test/11002.png
# test/11001.png
# test/10990.png
# test/10958.png
# test/10937.png
# test/10934.png
# test/10932.png
# test/10930.png
# test/10929.png
# test/10926.png
# test/10922.png
# test/10890.png
# test/1072.png
# test/1068.png
# test/1058.png
# test/1041.png
# test/988.png
# test/982.png
# test/969.png
# test/961.png
# test/948.png
# test/943.png
# test/920.png
# test/904.png
# test/901.png
# test/895.png
# test/867.png
# test/863.png
# test/842.png
# test/821.png
# test/817.png
# test/808.png
# test/805.png
# test/774.png
# test/769.png
# test/753.png
# test/734.png
# test/721.png
# test/716.png
# test/707.png
# test/682.png
# test/677.png
# test/667.png
# test/665.png
# test/648.png
# test/645.png
# test/643.png
# test/627.png
# test/624.png
# test/608.png
# test/594.png
# test/593.png
# test/564.png
# test/559.png
# test/534.png
# test/530.png
# test/504.png
# test/482.png
# test/477.png
# test/470.png
# test/446.png
# test/439.png
# test/412.png
# test/409.png
# test/408.png
# test/401.png
# test/392.png
# test/348.png
# test/345.png
# test/339.png
# test/337.png
# test/335.png
# test/320.png
# test/311.png
# test/306.png
# test/293.png
# test/292.png
# test/282.png
# test/262.png
# test/257.png
# test/248.png
# test/235.png
# test/232.png
# test/231.png
# test/230.png
# test/228.png
# test/207.png
# test/196.png
# test/159.png
# test/158.png
# test/132.png
# test/130.png
# test/124.png
# test/113.png
# test/95.png
# test/85.png
# test/80.png
# test/68.png
# test/43.png
# test/19.png
# test/13055.png
# test/13045.png
# test/see_bboxes.m
# test/13039.png
# test/13029.png
# test/13020.png
# test/13010.png
# test/13008.png
# test/13005.png
# test/12956.png
# test/12949.png
# test/12942.png
# test/12939.png
# test/12931.png
# test/12926.png
# test/12909.png
# test/12905.png
# test/12847.png
# test/12845.png
# test/12843.png
# test/12842.png
# test/12823.png
# test/12817.png
# test/12814.png
# test/12807.png
# test/12792.png
# test/12789.png
# test/12780.png
# test/12769.png
# test/12731.png
# test/12729.png
# test/12712.png
# test/12693.png
# test/12688.png
# test/12678.png
# test/12668.png
# test/12662.png
# test/12630.png
# test/12629.png
# test/12628.png
# test/2576.png
# test/2572.png
# test/2570.png
# test/2563.png
# test/2547.png
# test/2524.png
# test/2521.png
# test/2505.png
# test/2502.png
# test/2483.png
# test/2478.png
# test/2456.png
# test/2441.png
# test/2416.png
# test/2415.png
# test/2403.png
# test/2402.png
# test/2383.png
# test/2375.png
# test/2352.png
# test/2307.png
# test/2300.png
# test/2298.png
# test/2278.png
# test/2276.png
# test/2273.png
# test/2265.png
# test/2240.png
# test/2235.png
# test/2220.png
# test/2219.png
# test/2201.png
# test/2170.png
# test/2158.png
# test/2155.png
# test/2149.png
# test/2141.png
# test/2134.png
# test/2127.png
# test/2120.png
# test/2119.png
# test/2098.png
# test/2097.png
# test/2089.png
# test/2087.png
# test/2078.png
# test/2063.png
# test/2055.png
# test/2051.png
# test/2041.png
# test/2024.png
# test/2002.png
# test/1986.png
# test/1985.png
# test/1977.png
# test/1969.png
# test/1920.png
# test/1907.png
# test/1886.png
# test/1875.png
# test/1868.png
# test/1860.png
# test/1850.png
# test/1846.png
# test/1833.png
# test/1815.png
# test/1801.png
# test/1766.png
# test/1759.png
# test/1750.png
# test/1741.png
# test/1737.png
# test/1724.png
# test/1712.png
# test/1677.png
# test/1674.png
# test/1666.png
# test/1657.png
# test/1640.png
# test/1625.png
# test/1614.png
# test/1602.png
# test/1598.png
# test/1574.png
# test/1568.png
# test/1567.png
# test/1559.png
# test/1550.png
# test/1527.png
# test/1506.png
# test/1504.png
# test/1497.png
# test/1492.png
# test/1483.png
# test/1471.png
# test/1457.png
# test/1447.png
# test/1420.png
# test/1401.png
# test/1397.png
# test/1379.png
# test/1376.png
# test/1362.png
# test/1349.png
# test/1338.png
# test/1337.png
# test/1324.png
# test/1301.png
# test/1263.png
# test/1247.png
# test/1242.png
# test/1230.png
# test/1221.png
# test/1210.png
# test/1197.png
# test/1195.png
# test/1168.png
# test/1163.png
# test/1153.png
# test/1129.png
# test/1127.png
# test/1116.png
# test/1115.png
# test/1109.png
# test/1093.png
# test/1087.png
# test/1083.png
# test/1073.png
# test/4073.png
# test/4065.png
# test/4041.png
# test/4036.png
# test/4026.png
# test/4021.png
# test/4019.png
# test/4017.png
# test/4008.png
# test/4001.png
# test/3987.png
# test/3963.png
# test/3960.png
# test/3951.png
# test/3950.png
# test/3926.png
# test/3921.png
# test/3912.png
# test/3909.png
# test/3902.png
# test/3876.png
# test/3869.png
# test/3867.png
# test/3853.png
# test/3840.png
# test/3836.png
# test/3789.png
# test/3781.png
# test/3765.png
# test/3762.png
# test/3747.png
# test/3745.png
# test/3738.png
# test/3737.png
# test/3732.png
# test/3730.png
# test/3719.png
# test/3708.png
# test/3692.png
# test/3690.png
# test/3658.png
# test/3655.png
# test/3642.png
# test/3631.png
# test/3625.png
# test/3621.png
# test/3610.png
# test/3608.png
# test/3595.png
# test/3594.png
# test/3584.png
# test/3563.png
# test/3559.png
# test/3533.png
# test/3532.png
# test/3530.png
# test/3523.png
# test/3518.png
# test/3501.png
# test/3497.png
# test/3492.png
# test/3484.png
# test/3481.png
# test/3451.png
# test/3444.png
# test/3435.png
# test/3416.png
# test/3405.png
# test/3393.png
# test/3391.png
# test/3365.png
# test/3353.png
# test/3350.png
# test/3342.png
# test/3335.png
# test/3327.png
# test/3313.png
# test/3302.png
# test/3300.png
# test/3267.png
# test/3248.png
# test/3233.png
# test/3224.png
# test/3208.png
# test/3197.png
# test/3177.png
# test/3166.png
# test/3147.png
# test/3135.png
# test/3118.png
# test/3116.png
# test/3113.png
# test/3111.png
# test/3091.png
# test/3082.png
# test/3075.png
# test/3045.png
# test/3043.png
# test/3038.png
# test/3002.png
# test/2968.png
# test/2962.png
# test/2942.png
# test/2887.png
# test/2877.png
# test/2858.png
# test/2842.png
# test/2839.png
# test/2802.png
# test/2797.png
# test/2796.png
# test/2792.png
# test/2787.png
# test/2786.png
# test/2772.png
# test/2771.png
# test/2769.png
# test/2765.png
# test/2748.png
# test/2745.png
# test/2714.png
# test/2680.png
# test/2672.png
# test/2664.png
# test/2661.png
# test/2650.png
# test/2637.png
# test/2615.png
# test/5896.png
# test/5883.png
# test/5882.png
# test/5869.png
# test/5849.png
# test/5844.png
# test/5822.png
# test/5816.png
# test/5800.png
# test/5793.png
# test/5763.png
# test/5755.png
# test/5746.png
# test/5742.png
# test/5729.png
# test/5718.png
# test/5702.png
# test/5653.png
# test/5652.png
# test/5647.png
# test/5618.png
# test/5599.png
# test/5590.png
# test/5578.png
# test/5568.png
# test/5563.png
# test/5535.png
# test/5505.png
# test/5502.png
# test/5487.png
# test/5477.png
# test/5469.png
# test/5467.png
# test/5446.png
# test/5437.png
# test/5436.png
# test/5414.png
# test/5413.png
# test/5409.png
# test/5397.png
# test/5395.png
# test/5393.png
# test/5376.png
# test/5356.png
# test/5353.png
# test/5336.png
# test/5334.png
# test/5330.png
# test/5329.png
# test/5314.png
# test/5310.png
# test/5307.png
# test/5301.png
# test/5286.png
# test/5285.png
# test/5281.png
# test/5270.png
# test/5269.png
# test/5266.png
# test/5265.png
# test/5264.png
# test/5261.png
# test/5247.png
# test/5222.png
# test/5202.png
# test/5194.png
# test/5171.png
# test/5138.png
# test/5137.png
# test/5096.png
# test/5073.png
# test/5070.png
# test/5062.png
# test/5054.png
# test/4974.png
# test/4939.png
# test/4913.png
# test/4911.png
# test/4906.png
# test/4904.png
# test/4878.png
# test/4876.png
# test/4862.png
# test/4856.png
# test/4825.png
# test/4824.png
# test/4801.png
# test/4785.png
# test/4768.png
# test/4754.png
# test/4683.png
# test/4681.png
# test/4635.png
# test/4629.png
# test/4611.png
# test/4601.png
# test/4597.png
# test/4591.png
# test/4581.png
# test/4515.png
# test/4512.png
# test/4488.png
# test/4477.png
# test/4473.png
# test/4457.png
# test/4448.png
# test/4444.png
# test/4423.png
# test/4416.png
# test/4415.png
# test/4379.png
# test/4364.png
# test/4355.png
# test/4341.png
# test/4305.png
# test/4304.png
# test/4273.png
# test/4258.png
# test/4236.png
# test/4226.png
# test/4223.png
# test/4185.png
# test/4184.png
# test/4183.png
# test/4181.png
# test/4148.png
# test/4104.png
# test/4093.png
# test/7628.png
# test/7623.png
# test/7622.png
# test/7604.png
# test/7603.png
# test/7592.png
# test/7581.png
# test/7578.png
# test/7577.png
# test/7553.png
# test/7532.png
# test/7500.png
# test/7497.png
# test/7495.png
# test/7494.png
# test/7492.png
# test/7481.png
# test/7478.png
# test/7434.png
# test/7396.png
# test/7395.png
# test/7394.png
# test/7392.png
# test/7391.png
# test/7342.png
# test/7324.png
# test/7306.png
# test/7282.png
# test/7273.png
# test/7261.png
# test/7252.png
# test/7245.png
# test/7236.png
# test/7213.png
# test/7211.png
# test/7209.png
# test/7204.png
# test/7192.png
# test/7179.png
# test/7159.png
# test/7150.png
# test/7129.png
# test/7102.png
# test/7082.png
# test/7081.png
# test/7078.png
# test/7042.png
# test/7037.png
# test/7028.png
# test/7023.png
# test/7019.png
# test/7018.png
# test/7013.png
# test/6996.png
# test/6959.png
# test/6919.png
# test/6911.png
# test/6903.png
# test/6892.png
# test/6862.png
# test/6848.png
# test/6838.png
# test/6836.png
# test/6826.png
# test/6821.png
# test/6818.png
# test/6813.png
# test/6786.png
# test/6766.png
# test/6756.png
# test/6751.png
# test/6742.png
# test/6733.png
# test/6732.png
# test/6729.png
# test/6719.png
# test/6715.png
# test/6712.png
# test/6695.png
# test/6620.png
# test/6613.png
# test/6599.png
# test/6586.png
# test/6566.png
# test/6565.png
# test/6564.png
# test/6552.png
# test/6532.png
# test/6529.png
# test/6515.png
# test/6500.png
# test/6475.png
# test/6474.png
# test/6466.png
# test/6463.png
# test/6444.png
# test/6433.png
# test/6415.png
# test/6411.png
# test/6391.png
# test/6390.png
# test/6333.png
# test/6332.png
# test/6318.png
# test/6306.png
# test/6296.png
# test/6265.png
# test/6251.png
# test/6239.png
# test/6219.png
# test/6205.png
# test/6186.png
# test/6178.png
# test/6174.png
# test/6170.png
# test/6110.png
# test/6104.png
# test/6089.png
# test/6084.png
# test/6080.png
# test/6075.png
# test/6067.png
# test/6053.png
# test/6051.png
# test/6017.png
# test/5986.png
# test/5960.png
# test/5908.png
# test/9152.png
# test/9106.png
# test/9099.png
# test/9068.png
# test/9061.png
# test/9052.png
# test/9040.png
# test/9033.png
# test/9024.png
# test/9013.png
# test/8989.png
# test/8984.png
# test/8980.png
# test/8972.png
# test/8967.png
# test/8963.png
# test/8949.png
# test/8939.png
# test/8933.png
# test/8910.png
# test/8901.png
# test/8893.png
# test/8892.png
# test/8872.png
# test/8871.png
# test/8853.png
# test/8851.png
# test/8850.png
# test/8845.png
# test/8831.png
# test/8823.png
# test/8813.png
# test/8801.png
# test/8781.png
# test/8770.png
# test/8722.png
# test/8714.png
# test/8707.png
# test/8688.png
# test/8660.png
# test/8625.png
# test/8619.png
# test/8611.png
# test/8604.png
# test/8592.png
# test/8586.png
# test/8574.png
# test/8566.png
# test/8543.png
# test/8538.png
# test/8525.png
# test/8522.png
# test/8503.png
# test/8502.png
# test/8499.png
# test/8495.png
# test/8493.png
# test/8490.png
# test/8487.png
# test/8485.png
# test/8476.png
# test/8450.png
# test/8442.png
# test/8438.png
# test/8415.png
# test/8392.png
# test/8380.png
# test/8371.png
# test/8352.png
# test/8334.png
# test/8331.png
# test/8312.png
# test/8310.png
# test/8288.png
# test/8249.png
# test/8242.png
# test/8238.png
# test/8236.png
# test/8228.png
# test/8195.png
# test/8186.png
# test/8175.png
# test/8158.png
# test/8121.png
# test/8083.png
# test/8077.png
# test/8049.png
# test/8048.png
# test/8045.png
# test/8041.png
# test/8032.png
# test/8031.png
# test/8028.png
# test/8027.png
# test/7998.png
# test/7985.png
# test/7978.png
# test/7968.png
# test/7962.png
# test/7928.png
# test/7927.png
# test/7909.png
# test/7908.png
# test/7899.png
# test/7895.png
# test/7891.png
# test/7871.png
# test/7857.png
# test/7843.png
# test/7836.png
# test/7827.png
# test/7824.png
# test/7823.png
# test/7811.png
# test/7796.png
# test/7772.png
# test/7762.png
# test/7758.png
# test/7745.png
# test/7720.png
# test/7704.png
# test/7700.png
# test/7698.png
# test/7692.png
# test/7670.png
# test/7641.png
# test/7639.png
# test/7637.png
# test/10905.png
# test/10849.png
# test/10846.png
# test/10845.png
# test/10820.png
# test/10818.png
# test/10806.png
# test/10770.png
# test/10760.png
# test/10754.png
# test/10745.png
# test/10721.png
# test/10719.png
# test/10718.png
# test/10647.png
# test/10620.png
# test/10618.png
# test/10609.png
# test/10600.png
# test/10597.png
# test/10593.png
# test/10582.png
# test/10561.png
# test/10557.png
# test/10546.png
# test/10544.png
# test/10542.png
# test/10540.png
# test/10536.png
# test/10526.png
# test/10519.png
# test/10510.png
# test/10478.png
# test/10477.png
# test/10426.png
# test/10414.png
# test/10399.png
# test/10391.png
# test/10353.png
# test/10347.png
# test/10339.png
# test/10327.png
# test/10321.png
# test/10271.png
# test/10247.png
# test/10242.png
# test/10228.png
# test/10202.png
# test/10201.png
# test/10195.png
# test/10185.png
# test/10180.png
# test/10173.png
# test/10158.png
# test/10154.png
# test/10147.png
# test/10144.png
# test/10142.png
# test/10130.png
# test/10123.png
# test/10097.png
# test/10089.png
# test/10071.png
# test/10037.png
# test/10028.png
# test/10016.png
# test/9990.png
# test/9988.png
# test/9982.png
# test/9980.png
# test/9966.png
# test/9958.png
# test/9954.png
# test/9948.png
# test/9946.png
# test/9939.png
# test/9928.png
# test/9900.png
# test/9873.png
# test/9866.png
# test/9865.png
# test/9850.png
# test/9804.png
# test/9794.png
# test/9788.png
# test/9772.png
# test/9752.png
# test/9730.png
# test/9726.png
# test/9717.png
# test/9716.png
# test/9709.png
# test/9695.png
# test/9681.png
# test/9672.png
# test/9665.png
# test/9655.png
# test/9625.png
# test/9619.png
# test/9612.png
# test/9605.png
# test/9604.png
# test/9603.png
# test/9581.png
# test/9555.png
# test/9529.png
# test/9520.png
# test/9519.png
# test/9511.png
# test/9494.png
# test/9439.png
# test/9425.png
# test/9421.png
# test/9407.png
# test/9393.png
# test/9360.png
# test/9325.png
# test/9282.png
# test/9265.png
# test/9262.png
# test/9241.png
# test/9233.png
# test/9232.png
# test/9231.png
# test/9228.png
# test/9221.png
# test/9212.png
# test/9208.png
# test/12878.png
# test/12876.png
# test/12874.png
# test/12860.png
# test/12835.png
# test/12825.png
# test/12759.png
# test/12757.png
# test/12751.png
# test/12733.png
# test/12720.png
# test/12702.png
# test/12638.png
# test/12548.png
# test/12545.png
# test/12528.png
# test/12508.png
# test/12506.png
# test/12503.png
# test/12476.png
# test/12473.png
# test/12454.png
# test/12424.png
# test/12423.png
# test/12394.png
# test/12374.png
# test/12358.png
# test/12340.png
# test/12338.png
# test/12323.png
# test/12310.png
# test/12299.png
# test/12286.png
# test/12277.png
# test/12258.png
# test/12246.png
# test/12238.png
# test/13043.png
# test/12209.png
# test/12206.png
# test/12201.png
# test/12200.png
# test/12193.png
# test/12190.png
# test/12163.png
# test/12135.png
# test/12088.png
# test/12070.png
# test/12025.png
# test/12019.png
# test/12015.png
# test/12010.png
# test/11964.png
# test/11963.png
# test/11947.png
# test/11942.png
# test/11924.png
# test/11914.png
# test/11912.png
# test/11906.png
# test/11904.png
# test/11903.png
# test/11889.png
# test/11883.png
# test/11876.png
# test/11873.png
# test/11845.png
# test/11843.png
# test/11833.png
# test/11784.png
# test/11752.png
# test/11742.png
# test/11738.png
# test/11731.png
# test/11679.png
# test/11665.png
# test/11628.png
# test/11624.png
# test/11613.png
# test/11611.png
# test/11605.png
# test/11597.png
# test/11585.png
# test/11576.png
# test/11565.png
# test/11540.png
# test/11538.png
# test/11518.png
# test/11504.png
# test/11501.png
# test/11491.png
# test/11442.png
# test/11427.png
# test/11426.png
# test/11422.png
# test/11389.png
# test/11370.png
# test/11350.png
# test/11341.png
# test/11312.png
# test/11306.png
# test/11262.png
# test/11255.png
# test/11211.png
# test/11161.png
# test/11155.png
# test/11142.png
# test/11137.png
# test/11132.png
# test/11125.png
# test/11124.png
# test/11117.png
# test/11110.png
# test/11107.png
# test/11106.png
# test/11085.png
# test/11061.png
# test/11053.png
# test/11047.png
# test/11044.png
# test/11032.png
# test/11025.png
# test/11015.png
# test/11014.png
# test/10944.png
# test/10941.png
# test/10931.png
# test/10927.png
# test/1478.png
# test/1470.png
# test/1446.png
# test/1442.png
# test/1440.png
# test/1432.png
# test/1426.png
# test/1395.png
# test/1368.png
# test/1348.png
# test/1343.png
# test/1320.png
# test/1312.png
# test/1308.png
# test/1300.png
# test/1296.png
# test/1289.png
# test/1283.png
# test/1280.png
# test/1259.png
# test/1256.png
# test/1248.png
# test/1240.png
# test/1231.png
# test/1220.png
# test/1217.png
# test/1216.png
# test/1204.png
# test/1192.png
# test/1178.png
# test/1169.png
# test/1157.png
# test/1152.png
# test/1138.png
# test/1135.png
# test/1132.png
# test/1112.png
# test/1108.png
# test/1099.png
# test/1098.png
# test/1097.png
# test/1081.png
# test/1050.png
# test/1047.png
# test/1045.png
# test/1040.png
# test/1030.png
# test/1003.png
# test/965.png
# test/931.png
# test/930.png
# test/921.png
# test/916.png
# test/892.png
# test/873.png
# test/866.png
# test/865.png
# test/852.png
# test/841.png
# test/837.png
# test/812.png
# test/797.png
# test/759.png
# test/742.png
# test/729.png
# test/723.png
# test/706.png
# test/686.png
# test/680.png
# test/666.png
# test/640.png
# test/636.png
# test/635.png
# test/622.png
# test/587.png
# test/565.png
# test/545.png
# test/540.png
# test/516.png
# test/514.png
# test/513.png
# test/507.png
# test/499.png
# test/494.png
# test/464.png
# test/461.png
# test/453.png
# test/441.png
# test/423.png
# test/419.png
# test/384.png
# test/378.png
# test/375.png
# test/373.png
# test/297.png
# test/286.png
# test/280.png
# test/267.png
# test/251.png
# test/190.png
# test/189.png
# test/185.png
# test/168.png
# test/166.png
# test/160.png
# test/152.png
# test/94.png
# test/70.png
# test/60.png
# test/55.png
# test/37.png
# test/14.png
# test/13062.png
# test/13051.png
# test/13018.png
# test/12986.png
# test/12985.png
# test/12976.png
# test/12962.png
# test/12961.png
# test/12960.png
# test/12957.png
# test/12948.png
# test/12938.png
# test/12936.png
# test/12901.png
# test/12896.png
# test/12884.png
# test/3120.png
# test/3097.png
# test/3089.png
# test/3059.png
# test/3041.png
# test/3028.png
# test/3008.png
# test/3004.png
# test/3000.png
# test/2957.png
# test/2952.png
# test/2929.png
# test/2923.png
# test/2915.png
# test/2906.png
# test/2885.png
# test/2880.png
# test/2870.png
# test/2868.png
# test/2852.png
# test/2848.png
# test/2841.png
# test/2819.png
# test/2813.png
# test/2809.png
# test/2808.png
# test/2807.png
# test/2799.png
# test/2790.png
# test/2782.png
# test/2774.png
# test/2766.png
# test/2730.png
# test/2722.png
# test/2704.png
# test/2683.png
# test/2673.png
# test/2666.png
# test/2654.png
# test/2626.png
# test/2623.png
# test/2619.png
# test/2604.png
# test/2596.png
# test/2592.png
# test/2588.png
# test/2568.png
# test/2542.png
# test/2509.png
# test/2490.png
# test/2480.png
# test/2463.png
# test/2455.png
# test/2428.png
# test/2420.png
# test/2405.png
# test/2399.png
# test/2397.png
# test/2372.png
# test/2369.png
# test/2365.png
# test/2355.png
# test/2346.png
# test/2333.png
# test/2326.png
# test/2325.png
# test/2311.png
# test/2310.png
# test/2297.png
# test/2281.png
# test/2264.png
# test/2250.png
# test/2237.png
# test/2231.png
# test/2213.png
# test/2188.png
# test/2165.png
# test/2122.png
# test/2114.png
# test/2113.png
# test/2112.png
# test/2094.png
# test/2076.png
# test/2071.png
# test/2050.png
# test/2042.png
# test/2040.png
# test/2033.png
# test/2022.png
# test/2006.png
# test/2005.png
# test/1989.png
# test/1983.png
# test/1975.png
# test/1956.png
# test/1931.png
# test/1924.png
# test/1899.png
# test/1893.png
# test/1880.png
# test/1863.png
# test/1862.png
# test/1857.png
# test/1839.png
# test/1835.png
# test/1795.png
# test/1794.png
# test/1793.png
# test/1779.png
# test/1763.png
# test/1755.png
# test/1742.png
# test/1739.png
# test/1722.png
# test/1719.png
# test/1716.png
# test/1658.png
# test/1648.png
# test/1624.png
# test/1616.png
# test/1613.png
# test/1607.png
# test/1595.png
# test/1587.png
# test/1569.png
# test/1543.png
# test/1534.png
# test/1490.png
# test/4721.png
# test/4718.png
# test/4713.png
# test/4700.png
# test/4688.png
# test/4687.png
# test/4667.png
# test/4666.png
# test/4650.png
# test/4620.png
# test/4590.png
# test/4576.png
# test/4567.png
# test/4565.png
# test/4549.png
# test/4544.png
# test/4543.png
# test/4542.png
# test/4540.png
# test/4534.png
# test/4522.png
# test/4504.png
# test/4495.png
# test/4490.png
# test/4484.png
# test/4480.png
# test/4474.png
# test/4454.png
# test/4453.png
# test/4450.png
# test/4435.png
# test/4414.png
# test/4407.png
# test/4384.png
# test/4375.png
# test/4372.png
# test/4353.png
# test/4346.png
# test/4308.png
# test/4299.png
# test/4291.png
# test/4274.png
# test/4249.png
# test/4240.png
# test/4235.png
# test/4214.png
# test/4212.png
# test/4206.png
# test/4204.png
# test/4197.png
# test/4166.png
# test/4149.png
# test/4147.png
# test/4146.png
# test/4134.png
# test/4091.png
# test/4081.png
# test/4076.png
# test/4074.png
# test/4072.png
# test/4066.png
# test/4060.png
# test/4053.png
# test/4049.png
# test/4020.png
# test/3981.png
# test/3961.png
# test/3924.png
# test/3893.png
# test/3892.png
# test/3870.png
# test/3855.png
# test/3817.png
# test/3809.png
# test/3779.png
# test/3776.png
# test/3773.png
# test/3769.png
# test/3766.png
# test/3763.png
# test/3758.png
# test/3756.png
# test/3744.png
# test/3734.png
# test/3725.png
# test/3680.png
# test/3652.png
# test/3647.png
# test/3646.png
# test/3624.png
# test/3616.png
# test/3611.png
# test/3605.png
# test/3603.png
# test/3557.png
# test/3538.png
# test/3524.png
# test/3505.png
# test/3491.png
# test/3486.png
# test/3476.png
# test/3475.png
# test/3460.png
# test/3459.png
# test/3418.png
# test/3413.png
# test/3407.png
# test/3398.png
# test/3386.png
# test/3382.png
# test/3361.png
# test/3322.png
# test/3308.png
# test/3294.png
# test/3293.png
# test/3273.png
# test/3272.png
# test/3261.png
# test/3254.png
# test/3237.png
# test/3226.png
# test/3216.png
# test/3204.png
# test/3191.png
# test/3184.png
# test/3176.png
# test/3150.png
# test/3146.png
# test/6471.png
# test/6470.png
# test/6469.png
# test/6441.png
# test/6438.png
# test/6430.png
# test/6423.png
# test/6383.png
# test/6364.png
# test/6344.png
# test/6339.png
# test/6337.png
# test/6317.png
# test/6316.png
# test/6312.png
# test/6310.png
# test/6231.png
# test/6223.png
# test/6191.png
# test/6167.png
# test/6146.png
# test/6137.png
# test/6126.png
# test/6123.png
# test/6072.png
# test/6057.png
# test/6028.png
# test/6020.png
# test/6011.png
# test/6003.png
# test/5961.png
# test/5935.png
# test/5924.png
# test/5907.png
# test/5902.png
# test/5884.png
# test/5881.png
# test/5874.png
# test/5872.png
# test/5842.png
# test/5835.png
# test/5823.png
# test/5812.png
# test/5786.png
# test/5784.png
# test/5783.png
# test/5781.png
# test/5770.png
# test/5759.png
# test/5757.png
# test/5741.png
# test/5725.png
# test/5713.png
# test/5706.png
# test/5695.png
# test/5688.png
# test/5682.png
# test/5670.png
# test/5626.png
# test/5611.png
# test/5597.png
# test/5566.png
# test/5565.png
# test/5561.png
# test/5554.png
# test/5546.png
# test/5543.png
# test/5542.png
# test/5531.png
# test/5513.png
# test/5498.png
# test/5428.png
# test/5399.png
# test/5390.png
# test/5374.png
# test/5363.png
# test/5344.png
# test/5308.png
# test/5300.png
# test/5267.png
# test/5262.png
# test/5239.png
# test/5234.png
# test/5228.png
# test/5227.png
# test/5226.png
# test/5221.png
# test/5217.png
# test/5212.png
# test/5198.png
# test/5191.png
# test/5183.png
# test/5154.png
# test/5140.png
# test/5132.png
# test/5131.png
# test/5127.png
# test/5116.png
# test/5108.png
# test/5093.png
# test/5077.png
# test/5045.png
# test/5043.png
# test/5041.png
# test/5040.png
# test/5038.png
# test/4998.png
# test/4990.png
# test/4988.png
# test/4976.png
# test/4952.png
# test/4941.png
# test/4932.png
# test/4917.png
# test/4899.png
# test/4893.png
# test/4872.png
# test/4865.png
# test/4836.png
# test/4822.png
# test/4810.png
# test/4793.png
# test/4780.png
# test/4770.png
# test/4745.png
# test/4735.png
# test/4732.png
# test/4726.png
# test/7971.png
# test/7960.png
# test/7958.png
# test/7952.png
# test/7937.png
# test/7924.png
# test/7919.png
# test/7903.png
# test/7884.png
# test/7792.png
# test/7791.png
# test/7771.png
# test/7757.png
# test/7754.png
# test/7737.png
# test/7717.png
# test/7697.png
# test/7693.png
# test/7690.png
# test/7687.png
# test/7679.png
# test/7669.png
# test/7644.png
# test/7640.png
# test/7629.png
# test/7626.png
# test/7619.png
# test/7615.png
# test/7613.png
# test/7612.png
# test/7596.png
# test/7586.png
# test/7584.png
# test/7583.png
# test/7565.png
# test/7563.png
# test/7552.png
# test/7550.png
# test/7526.png
# test/7499.png
# test/7486.png
# test/7484.png
# test/7483.png
# test/7476.png
# test/7455.png
# test/7445.png
# test/7443.png
# test/7419.png
# test/7413.png
# test/7349.png
# test/7345.png
# test/7337.png
# test/7336.png
# test/7320.png
# test/7293.png
# test/7274.png
# test/7271.png
# test/7244.png
# test/7235.png
# test/7230.png
# test/7220.png
# test/7202.png
# test/7197.png
# test/7186.png
# test/7180.png
# test/7171.png
# test/7162.png
# test/7153.png
# test/7135.png
# test/7134.png
# test/7115.png
# test/7114.png
# test/7112.png
# test/7074.png
# test/7068.png
# test/7057.png
# test/7050.png
# test/7034.png
# test/7021.png
# test/7012.png
# test/7007.png
# test/7001.png
# test/6968.png
# test/6963.png
# test/6952.png
# test/6945.png
# test/6920.png
# test/6913.png
# test/6905.png
# test/6901.png
# test/6888.png
# test/6878.png
# test/6874.png
# test/6868.png
# test/6860.png
# test/6844.png
# test/6842.png
# test/6829.png
# test/6823.png
# test/6815.png
# test/6770.png
# test/6762.png
# test/6760.png
# test/6757.png
# test/6743.png
# test/6721.png
# test/6714.png
# test/6686.png
# test/6657.png
# test/6645.png
# test/6637.png
# test/6635.png
# test/6623.png
# test/6600.png
# test/6580.png
# test/6576.png
# test/6575.png
# test/6571.png
# test/6568.png
# test/6553.png
# test/6549.png
# test/6538.png
# test/6528.png
# test/6523.png
# test/6520.png
# test/6512.png
# test/6509.png
# test/6494.png
# test/9784.png
# test/9783.png
# test/9778.png
# test/9774.png
# test/9754.png
# test/9744.png
# test/9728.png
# test/9700.png
# test/9678.png
# test/9642.png
# test/9641.png
# test/9639.png
# test/9637.png
# test/9636.png
# test/9624.png
# test/9593.png
# test/9565.png
# test/9556.png
# test/9553.png
# test/9552.png
# test/9531.png
# test/9528.png
# test/9515.png
# test/9512.png
# test/9502.png
# test/9492.png
# test/9467.png
# test/9441.png
# test/9430.png
# test/9428.png
# test/9423.png
# test/9368.png
# test/9367.png
# test/9355.png
# test/9338.png
# test/9329.png
# test/9321.png
# test/9296.png
# test/9287.png
# test/9286.png
# test/9285.png
# test/9272.png
# test/9271.png
# test/9245.png
# test/9215.png
# test/9202.png
# test/9173.png
# test/9147.png
# test/9139.png
# test/9117.png
# test/9115.png
# test/9101.png
# test/9056.png
# test/9049.png
# test/9037.png
# test/9025.png
# test/9011.png
# test/8988.png
# test/8973.png
# test/8955.png
# test/8941.png
# test/8936.png
# test/8908.png
# test/8907.png
# test/8903.png
# test/8900.png
# test/8899.png
# test/8896.png
# test/8864.png
# test/8840.png
# test/8835.png
# test/8820.png
# test/8807.png
# test/8797.png
# test/8796.png
# test/8794.png
# test/8793.png
# test/8792.png
# test/8782.png
# test/8779.png
# test/8735.png
# test/8715.png
# test/8701.png
# test/8699.png
# test/8676.png
# test/8650.png
# test/8622.png
# test/8589.png
# test/8581.png
# test/8578.png
# test/8541.png
# test/8540.png
# test/8527.png
# test/8520.png
# test/8494.png
# test/8483.png
# test/8472.png
# test/8469.png
# test/8447.png
# test/8430.png
# test/8391.png
# test/8388.png
# test/8370.png
# test/8369.png
# test/8366.png
# test/8350.png
# test/8345.png
# test/8315.png
# test/8307.png
# test/8282.png
# test/8227.png
# test/8215.png
# test/8209.png
# test/8205.png
# test/8192.png
# test/8159.png
# test/8145.png
# test/8113.png
# test/8112.png
# test/8109.png
# test/8106.png
# test/8088.png
# test/8050.png
# test/8047.png
# test/8042.png
# test/8023.png
# test/8022.png
# test/8017.png
# test/11401.png
# test/11375.png
# test/11367.png
# test/11363.png
# test/11356.png
# test/11352.png
# test/11346.png
# test/11323.png
# test/11321.png
# test/11320.png
# test/11318.png
# test/11299.png
# test/11296.png
# test/11282.png
# test/11278.png
# test/11266.png
# test/11260.png
# test/11258.png
# test/11252.png
# test/11250.png
# test/11234.png
# test/11225.png
# test/11199.png
# test/11168.png
# test/11167.png
# test/11150.png
# test/11133.png
# test/11092.png
# test/11083.png
# test/11080.png
# test/11079.png
# test/11074.png
# test/11071.png
# test/11059.png
# test/11052.png
# test/11033.png
# test/11021.png
# test/11020.png
# test/11005.png
# test/10983.png
# test/10968.png
# test/10965.png
# test/10960.png
# test/10948.png
# test/10936.png
# test/10933.png
# test/10916.png
# test/10913.png
# test/10899.png
# test/10896.png
# test/10894.png
# test/10875.png
# test/10874.png
# test/10862.png
# test/10851.png
# test/10850.png
# test/10844.png
# test/10832.png
# test/10809.png
# test/10782.png
# test/10777.png
# test/10746.png
# test/10740.png
# test/10739.png
# test/10738.png
# test/10730.png
# test/10729.png
# test/10723.png
# test/10722.png
# test/10636.png
# test/10634.png
# test/10631.png
# test/10629.png
# test/10627.png
# test/10590.png
# test/10520.png
# test/10517.png
# test/10485.png
# test/10474.png
# test/10462.png
# test/10451.png
# test/10429.png
# test/10393.png
# test/10383.png
# test/10374.png
# test/10371.png
# test/10368.png
# test/10345.png
# test/10344.png
# test/10318.png
# test/10295.png
# test/10246.png
# test/10199.png
# test/10170.png
# test/10155.png
# test/10149.png
# test/10119.png
# test/10118.png
# test/10114.png
# test/10113.png
# test/10104.png
# test/10102.png
# test/10075.png
# test/10073.png
# test/10056.png
# test/10041.png
# test/10040.png
# test/10005.png
# test/9979.png
# test/9977.png
# test/9969.png
# test/9967.png
# test/9962.png
# test/9960.png
# test/9945.png
# test/9938.png
# test/9922.png
# test/9908.png
# test/9902.png
# test/9891.png
# test/9890.png
# test/9886.png
# test/9884.png
# test/9879.png
# test/9848.png
# test/9834.png
# test/9797.png
# test/9785.png
# test/76.png
# test/73.png
# test/61.png
# test/49.png
# test/30.png
# test/27.png
# test/7.png
# test/3.png
# test/13059.png
# test/13053.png
# test/13044.png
# test/13033.png
# test/13032.png
# test/13023.png
# test/13004.png
# test/12996.png
# test/12989.png
# test/12984.png
# test/12968.png
# test/12941.png
# test/12925.png
# test/12924.png
# test/12920.png
# test/12918.png
# test/12916.png
# test/12903.png
# test/12886.png
# test/12882.png
# test/12880.png
# test/12869.png
# test/12853.png
# test/12827.png
# test/12791.png
# test/12764.png
# test/12728.png
# test/12726.png
# test/12707.png
# test/12684.png
# test/12679.png
# test/12675.png
# test/12674.png
# test/12608.png
# test/12588.png
# test/12581.png
# test/12563.png
# test/12561.png
# test/12554.png
# test/12534.png
# test/12531.png
# test/12524.png
# test/12514.png
# test/12511.png
# test/12504.png
# test/12497.png
# test/12493.png
# test/12490.png
# test/12478.png
# test/12465.png
# test/12462.png
# test/12460.png
# test/12449.png
# test/12445.png
# test/12431.png
# test/12409.png
# test/12406.png
# test/12400.png
# test/12375.png
# test/12370.png
# test/12365.png
# test/12346.png
# test/12312.png
# test/12297.png
# test/12282.png
# test/12280.png
# test/12279.png
# test/12239.png
# test/12235.png
# test/12230.png
# test/12214.png
# test/12179.png
# test/12178.png
# test/12174.png
# test/12164.png
# test/12140.png
# test/12130.png
# test/12060.png
# test/12059.png
# test/12054.png
# test/12051.png
# test/12030.png
# test/12024.png
# test/11999.png
# test/11984.png
# test/11973.png
# test/11959.png
# test/11953.png
# test/11952.png
# test/11926.png
# test/11915.png
# test/11908.png
# test/11797.png
# test/11787.png
# test/11786.png
# test/11766.png
# test/11736.png
# test/11723.png
# test/11719.png
# test/11689.png
# test/11668.png
# test/11652.png
# test/11651.png
# test/11614.png
# test/11590.png
# test/11587.png
# test/11583.png
# test/11577.png
# test/11574.png
# test/11567.png
# test/11564.png
# test/11560.png
# test/11555.png
# test/11545.png
# test/11535.png
# test/11532.png
# test/11522.png
# test/11521.png
# test/11496.png
# test/11409.png
# test/1521.png
# test/1520.png
# test/1515.png
# test/1510.png
# test/1505.png
# test/1503.png
# test/1495.png
# test/1476.png
# test/1453.png
# test/1436.png
# test/1414.png
# test/1408.png
# test/1406.png
# test/1380.png
# test/1346.png
# test/1345.png
# test/1331.png
# test/1313.png
# test/1304.png
# test/1297.png
# test/1279.png
# test/1268.png
# test/1266.png
# test/1258.png
# test/1236.png
# test/1224.png
# test/1209.png
# test/1190.png
# test/1170.png
# test/1161.png
# test/1159.png
# test/1155.png
# test/1122.png
# test/1110.png
# test/1076.png
# test/1074.png
# test/1021.png
# test/1013.png
# test/1011.png
# test/996.png
# test/966.png
# test/955.png
# test/953.png
# test/941.png
# test/933.png
# test/924.png
# test/922.png
# test/910.png
# test/893.png
# test/882.png
# test/881.png
# test/862.png
# test/840.png
# test/836.png
# test/831.png
# test/822.png
# test/819.png
# test/818.png
# test/811.png
# test/787.png
# test/773.png
# test/768.png
# test/767.png
# test/762.png
# test/761.png
# test/748.png
# test/745.png
# test/725.png
# test/709.png
# test/704.png
# test/688.png
# test/687.png
# test/674.png
# test/671.png
# test/650.png
# test/620.png
# test/618.png
# test/612.png
# test/607.png
# test/602.png
# test/600.png
# test/586.png
# test/573.png
# test/560.png
# test/551.png
# test/529.png
# test/503.png
# test/498.png
# test/497.png
# test/493.png
# test/472.png
# test/468.png
# test/438.png
# test/398.png
# test/396.png
# test/394.png
# test/391.png
# test/380.png
# test/369.png
# test/340.png
# test/338.png
# test/334.png
# test/321.png
# test/308.png
# test/300.png
# test/290.png
# test/287.png
# test/283.png
# test/279.png
# test/221.png
# test/220.png
# test/205.png
# test/200.png
# test/181.png
# test/180.png
# test/174.png
# test/171.png
# test/167.png
# test/154.png
# test/147.png
# test/141.png
# test/139.png
# test/137.png
# test/135.png
# test/101.png
# test/93.png
# test/89.png
# test/81.png
# test/3257.png
# test/3243.png
# test/3238.png
# test/3223.png
# test/3221.png
# test/3168.png
# test/3149.png
# test/3141.png
# test/3140.png
# test/3128.png
# test/3107.png
# test/3105.png
# test/3103.png
# test/3085.png
# test/3052.png
# test/3044.png
# test/3030.png
# test/3020.png
# test/3003.png
# test/2995.png
# test/2944.png
# test/2941.png
# test/2920.png
# test/2919.png
# test/2850.png
# test/2836.png
# test/2833.png
# test/2832.png
# test/2830.png
# test/2824.png
# test/2776.png
# test/2773.png
# test/2764.png
# test/2761.png
# test/2760.png
# test/2747.png
# test/2739.png
# test/2732.png
# test/2725.png
# test/2685.png
# test/2676.png
# test/2674.png
# test/2668.png
# test/2663.png
# test/2656.png
# test/2597.png
# test/2569.png
# test/2562.png
# test/2551.png
# test/2546.png
# test/2486.png
# test/2482.png
# test/2466.png
# test/2449.png
# test/2438.png
# test/2429.png
# test/2387.png
# test/2384.png
# test/2382.png
# test/2376.png
# test/2374.png
# test/2359.png
# test/2348.png
# test/2336.png
# test/2335.png
# test/2308.png
# test/2301.png
# test/2294.png
# test/2282.png
# test/2268.png
# test/2267.png
# test/2261.png
# test/2256.png
# test/2218.png
# test/2212.png
# test/2202.png
# test/2187.png
# test/2179.png
# test/2162.png
# test/2110.png
# test/2102.png
# test/2100.png
# test/2096.png
# test/2095.png
# test/2088.png
# test/2084.png
# test/2068.png
# test/2067.png
# test/2056.png
# test/2045.png
# test/2037.png
# test/2020.png
# test/2019.png
# test/2012.png
# test/1971.png
# test/1967.png
# test/1966.png
# test/1960.png
# test/1946.png
# test/1932.png
# test/1921.png
# test/1913.png
# test/1898.png
# test/1881.png
# test/1864.png
# test/1853.png
# test/1851.png
# test/1841.png
# test/1828.png
# test/1820.png
# test/1816.png
# test/1807.png
# test/1789.png
# test/1781.png
# test/1762.png
# test/1751.png
# test/1692.png
# test/1687.png
# test/1673.png
# test/1670.png
# test/1634.png
# test/1615.png
# test/1612.png
# test/1562.png
# test/1552.png
# test/1542.png
# test/1540.png
# test/1522.png
# test/4982.png
# test/4981.png
# test/4935.png
# test/4931.png
# test/4926.png
# test/4907.png
# test/4889.png
# test/4888.png
# test/4863.png
# test/4859.png
# test/4854.png
# test/4846.png
# test/4843.png
# test/4815.png
# test/4802.png
# test/4800.png
# test/4790.png
# test/4788.png
# test/4778.png
# test/4746.png
# test/4744.png
# test/4738.png
# test/4731.png
# test/4717.png
# test/4709.png
# test/4706.png
# test/4694.png
# test/4671.png
# test/4648.png
# test/4636.png
# test/4610.png
# test/4573.png
# test/4572.png
# test/4541.png
# test/4533.png
# test/4519.png
# test/4502.png
# test/4499.png
# test/4438.png
# test/4427.png
# test/4422.png
# test/4419.png
# test/4406.png
# test/4402.png
# test/4392.png
# test/4376.png
# test/4366.png
# test/4360.png
# test/4334.png
# test/4324.png
# test/4314.png
# test/4306.png
# test/4301.png
# test/4300.png
# test/4296.png
# test/4288.png
# test/4287.png
# test/4283.png
# test/4266.png
# test/4239.png
# test/4234.png
# test/4180.png
# test/4172.png
# test/4165.png
# test/4160.png
# test/4158.png
# test/4153.png
# test/4152.png
# test/4143.png
# test/4136.png
# test/4100.png
# test/4087.png
# test/4045.png
# test/4043.png
# test/4025.png
# test/4015.png
# test/3993.png
# test/3985.png
# test/3968.png
# test/3938.png
# test/3927.png
# test/3885.png
# test/3884.png
# test/3868.png
# test/3860.png
# test/3850.png
# test/3834.png
# test/3833.png
# test/3805.png
# test/3759.png
# test/3757.png
# test/3746.png
# test/3721.png
# test/3693.png
# test/3659.png
# test/3626.png
# test/3620.png
# test/3612.png
# test/3600.png
# test/3577.png
# test/3569.png
# test/3549.png
# test/3504.png
# test/3473.png
# test/3457.png
# test/3455.png
# test/3436.png
# test/3425.png
# test/3423.png
# test/3356.png
# test/3351.png
# test/3345.png
# test/3338.png
# test/3337.png
# test/3336.png
# test/3334.png
# test/3328.png
# test/3325.png
# test/3309.png
# test/3299.png
# test/3297.png
# test/3286.png
# test/3282.png
# test/3281.png
# test/3279.png
# test/3274.png
# test/3271.png
# test/3270.png
# test/6914.png
# test/6882.png
# test/6881.png
# test/6839.png
# test/6832.png
# test/6801.png
# test/6799.png
# test/6778.png
# test/6739.png
# test/6737.png
# test/6718.png
# test/6698.png
# test/6692.png
# test/6667.png
# test/6654.png
# test/6612.png
# test/6582.png
# test/6560.png
# test/6537.png
# test/6522.png
# test/6519.png
# test/6504.png
# test/6492.png
# test/6461.png
# test/6437.png
# test/6432.png
# test/6429.png
# test/6419.png
# test/6417.png
# test/6410.png
# test/6399.png
# test/6388.png
# test/6386.png
# test/6369.png
# test/6365.png
# test/6350.png
# test/6309.png
# test/6305.png
# test/6300.png
# test/6285.png
# test/6281.png
# test/6274.png
# test/6249.png
# test/6232.png
# test/6229.png
# test/6216.png
# test/6183.png
# test/6176.png
# test/6145.png
# test/6131.png
# test/6130.png
# test/6128.png
# test/6124.png
# test/6112.png
# test/6102.png
# test/6097.png
# test/6058.png
# test/6006.png
# test/5995.png
# test/5991.png
# test/5988.png
# test/5975.png
# test/5971.png
# test/5969.png
# test/5968.png
# test/5966.png
# test/5946.png
# test/5945.png
# test/5940.png
# test/5932.png
# test/5918.png
# test/5916.png
# ...
# test/12752.png
# test/12722.png
# test/12716.png
# test/12709.png
# test/12704.png
# test/12699.png
# test/12686.png
# test/12665.png
# test/12654.png
# test/12646.png
# test/12644.png
# test/12617.png
# test/12606.png
# test/12571.png
# test/12569.png
# test/12547.png
# test/12537.png
# test/12530.png
# test/12527.png
# test/12521.png
# test/12519.png
# test/12461.png
# test/12456.png
# test/12452.png
# test/12439.png
# test/12417.png
# test/12401.png
# test/12384.png
# test/12382.png
# test/12371.png
# test/12366.png
# test/12361.png
# test/12357.png
# test/12355.png
# test/12347.png
# test/12328.png
# test/12327.png
# test/12321.png
# test/12304.png
# test/12298.png
# test/12295.png
# test/12289.png
# test/12274.png
# test/12253.png
# test/12208.png
# test/12203.png
# test/12169.png
# test/12146.png
# test/12145.png
# test/12144.png
# test/12133.png
# test/12126.png
# test/12122.png
# test/12110.png
# test/12093.png
# test/12083.png
# test/12074.png
# test/12073.png
# test/12072.png
# test/12056.png
# test/12035.png
# test/12028.png
# test/12006.png
# test/11986.png
# test/11979.png
# test/11962.png
# test/11961.png
# test/11941.png
# test/11921.png
# test/11899.png
# test/11882.png
# test/11870.png
# test/11869.png
# test/11868.png
# test/11866.png
# test/11858.png
# test/11856.png
# test/11831.png
# test/11812.png
# test/11811.png
# test/11774.png
# test/11763.png
# test/11757.png
# test/2290.png
# test/2277.png
# test/2253.png
# test/2246.png
# test/2244.png
# test/2242.png
# test/2230.png
# test/2221.png
# test/2196.png
# test/2195.png
# test/2169.png
# test/2115.png
# test/2101.png
# test/2074.png
# test/2072.png
# test/2070.png
# test/2054.png
# test/2044.png
# test/2021.png
# test/2009.png
# test/1925.png
# test/1889.png
# test/1855.png
# test/1845.png
# test/1842.png
# test/1840.png
# test/1824.png
# test/1805.png
# test/1777.png
# test/1752.png
# test/1709.png
# test/1690.png
# test/1664.png
# test/1655.png
# test/1652.png
# test/1644.png
# test/1639.png
# test/1638.png
# test/1637.png
# test/1623.png
# test/1611.png
# test/1593.png
# test/1573.png
# test/1536.png
# test/1519.png
# test/1496.png
# test/1477.png
# test/1472.png
# test/1468.png
# test/1448.png
# test/1444.png
# test/1443.png
# test/1429.png
# test/1425.png
# test/1417.png
# test/1372.png
# test/1371.png
# test/1367.png
# test/1352.png
# test/1329.png
# test/1327.png
# test/1326.png
# test/1318.png
# test/1305.png
# test/1292.png
# test/1286.png
# test/1260.png
# test/1241.png
# test/1218.png
# test/1213.png
# test/1206.png
# test/1200.png
# test/1151.png
# test/1144.png
# test/1131.png
# test/1121.png
# test/1119.png
# test/1113.png
# test/1096.png
# test/1065.png
# test/1036.png
# test/1024.png
# test/1005.png
# test/993.png
# test/992.png
# test/974.png
# test/959.png
# test/954.png
# test/952.png
# test/945.png
# test/940.png
# test/887.png
# test/886.png
# test/878.png
# test/827.png
# test/815.png
# test/810.png
# test/801.png
# test/795.png
# test/785.png
# test/766.png
# test/760.png
# test/710.png
# test/693.png
# test/678.png
# test/661.png
# test/656.png
# test/621.png
# test/617.png
# test/610.png
# test/567.png
# test/552.png
# test/543.png
# test/524.png
# test/505.png
# test/502.png
# test/487.png
# test/484.png
# test/467.png
# test/440.png
# test/429.png
# test/417.png
# test/362.png
# test/359.png
# test/355.png
# test/353.png
# test/333.png
# test/331.png
# test/4052.png
# test/4032.png
# test/4028.png
# test/4027.png
# test/3999.png
# test/3969.png
# test/3966.png
# test/3962.png
# test/3956.png
# test/3941.png
# test/3936.png
# test/3911.png
# test/3910.png
# test/3904.png
# test/3859.png
# test/3848.png
# test/3841.png
# test/3837.png
# test/3830.png
# test/3797.png
# test/3792.png
# test/3788.png
# test/3782.png
# test/3775.png
# test/3774.png
# test/3768.png
# test/3739.png
# test/3716.png
# test/3715.png
# test/3695.png
# test/3685.png
# test/3672.png
# test/3663.png
# test/3651.png
# test/3633.png
# test/3622.png
# test/3607.png
# test/3599.png
# test/3598.png
# test/3525.png
# test/3519.png
# test/3515.png
# test/3506.png
# test/3500.png
# test/3496.png
# test/3447.png
# test/3441.png
# test/3440.png
# test/3404.png
# test/3372.png
# test/3369.png
# test/3348.png
# test/3292.png
# test/3283.png
# test/3246.png
# test/3231.png
# test/3199.png
# test/3179.png
# test/3153.png
# test/3144.png
# test/3130.png
# test/3114.png
# test/3102.png
# test/3093.png
# test/3084.png
# test/3081.png
# test/3069.png
# test/3054.png
# test/3049.png
# test/3029.png
# test/3005.png
# test/2990.png
# test/2986.png
# test/2954.png
# test/2947.png
# test/2933.png
# test/2894.png
# test/2893.png
# test/2891.png
# test/2884.png
# test/2883.png
# test/2879.png
# test/2878.png
# test/2871.png
# test/2861.png
# test/2854.png
# test/2849.png
# test/2840.png
# test/2805.png
# test/2793.png
# test/2783.png
# test/2778.png
# test/2770.png
# test/2767.png
# test/2762.png
# test/2757.png
# test/2756.png
# test/2717.png
# test/2713.png
# test/2707.png
# test/2695.png
# test/2678.png
# test/2662.png
# test/2655.png
# test/2616.png
# test/2611.png
# test/2594.png
# test/2567.png
# test/2552.png
# test/2536.png
# test/2511.png
# test/2479.png
# test/2469.png
# test/2465.png
# test/2451.png
# test/2445.png
# test/2436.png
# test/2412.png
# test/2410.png
# test/2404.png
# test/2396.png
# test/2373.png
# test/2370.png
# test/2345.png
# test/2318.png
# test/2303.png
# test/2299.png
# test/2291.png
# test/5794.png
# test/5791.png
# test/5785.png
# test/5771.png
# test/5765.png
# test/5750.png
# test/5704.png
# test/5665.png
# test/5637.png
# test/5600.png
# test/5598.png
# test/5593.png
# test/5588.png
# test/5569.png
# test/5562.png
# test/5559.png
# test/5507.png
# test/5470.png
# test/5449.png
# test/5421.png
# test/5402.png
# test/5388.png
# test/5385.png
# test/5375.png
# test/5364.png
# test/5354.png
# test/5346.png
# test/5320.png
# test/5284.png
# test/5277.png
# test/5276.png
# test/5256.png
# test/5252.png
# test/5245.png
# test/5182.png
# test/5159.png
# test/5156.png
# test/5152.png
# test/5147.png
# test/5135.png
# test/5115.png
# test/5111.png
# test/5072.png
# test/5068.png
# test/5060.png
# test/5055.png
# test/5053.png
# test/5050.png
# test/5033.png
# test/5031.png
# test/5028.png
# test/5021.png
# test/5003.png
# test/4989.png
# test/4984.png
# test/4978.png
# test/4956.png
# test/4946.png
# test/4944.png
# test/4938.png
# test/4934.png
# test/4930.png
# test/4910.png
# test/4898.png
# test/4852.png
# test/4850.png
# test/4837.png
# test/4817.png
# test/4812.png
# test/4811.png
# test/4808.png
# test/4761.png
# test/4715.png
# test/4699.png
# test/4672.png
# test/4660.png
# test/4634.png
# test/4627.png
# test/4588.png
# test/4570.png
# test/4559.png
# test/4553.png
# test/4547.png
# test/4545.png
# test/4513.png
# test/4505.png
# test/4497.png
# test/4478.png
# test/4475.png
# test/4470.png
# test/4463.png
# test/4462.png
# test/4445.png
# test/4432.png
# test/4409.png
# test/4395.png
# test/4390.png
# test/4389.png
# test/4361.png
# test/4352.png
# test/4351.png
# test/4329.png
# test/4275.png
# test/4260.png
# test/4248.png
# test/4247.png
# test/4238.png
# test/4227.png
# test/4225.png
# test/4211.png
# test/4194.png
# test/4178.png
# test/4177.png
# test/4168.png
# test/4164.png
# test/4157.png
# test/4156.png
# test/4151.png
# test/4138.png
# test/4125.png
# test/4123.png
# test/4121.png
# test/4114.png
# test/4112.png
# test/4103.png
# test/4077.png
# test/4068.png
# test/4057.png
# test/7463.png
# test/7446.png
# test/7437.png
# test/7429.png
# test/7417.png
# test/7406.png
# test/7389.png
# test/7387.png
# test/7383.png
# test/7376.png
# test/7363.png
# test/7359.png
# test/7353.png
# test/7333.png
# test/7332.png
# test/7287.png
# test/7276.png
# test/7262.png
# test/7260.png
# test/7259.png
# test/7254.png
# test/7242.png
# test/7233.png
# test/7225.png
# test/7219.png
# test/7208.png
# test/7176.png
# test/7161.png
# test/7144.png
# test/7120.png
# test/7117.png
# test/7096.png
# test/7086.png
# test/7085.png
# test/7071.png
# test/7053.png
# test/7051.png
# test/7030.png
# test/7010.png
# test/7004.png
# test/6992.png
# test/6988.png
# test/6969.png
# test/6942.png
# test/6908.png
# test/6907.png
# test/6873.png
# test/6831.png
# test/6812.png
# test/6807.png
# test/6797.png
# test/6794.png
# test/6774.png
# test/6745.png
# test/6744.png
# test/6734.png
# test/6724.png
# test/6663.png
# test/6655.png
# test/6653.png
# test/6646.png
# test/6639.png
# test/6632.png
# test/6603.png
# test/6593.png
# test/6581.png
# test/6555.png
# test/6540.png
# test/6511.png
# test/6510.png
# test/6497.png
# test/6493.png
# test/6480.png
# test/6465.png
# test/6447.png
# test/6443.png
# test/6426.png
# test/6418.png
# test/6409.png
# test/6398.png
# test/6397.png
# test/6395.png
# test/6378.png
# test/6371.png
# test/6354.png
# test/6315.png
# test/6301.png
# test/6290.png
# test/6275.png
# test/6264.png
# test/6255.png
# test/6237.png
# test/6217.png
# test/6214.png
# test/6210.png
# test/6200.png
# test/6194.png
# test/6175.png
# test/6160.png
# test/6158.png
# test/6157.png
# test/6150.png
# test/6148.png
# test/6147.png
# test/6142.png
# test/6125.png
# test/6122.png
# test/6113.png
# test/6086.png
# test/6076.png
# test/6066.png
# test/6065.png
# test/6063.png
# test/6061.png
# test/6048.png
# test/6024.png
# test/5994.png
# test/5993.png
# test/5970.png
# test/5958.png
# test/5914.png
# test/5906.png
# test/5901.png
# test/5900.png
# test/5870.png
# test/5852.png
# test/5834.png
# test/5805.png
# test/9043.png
# test/9042.png
# test/9039.png
# test/8982.png
# test/8952.png
# test/8950.png
# test/8946.png
# test/8940.png
# test/8931.png
# test/8922.png
# test/8919.png
# test/8916.png
# test/8915.png
# test/8909.png
# test/8897.png
# test/8894.png
# test/8873.png
# test/8868.png
# test/8861.png
# test/8834.png
# test/8816.png
# test/8814.png
# test/8809.png
# test/8803.png
# test/8798.png
# test/8791.png
# test/8773.png
# test/8769.png
# test/8765.png
# test/8745.png
# test/8743.png
# test/8727.png
# test/8725.png
# test/8713.png
# test/8712.png
# test/8683.png
# test/8670.png
# test/8658.png
# test/8656.png
# test/8639.png
# test/8635.png
# test/8634.png
# test/8609.png
# test/8603.png
# test/8580.png
# test/8576.png
# test/8570.png
# test/8563.png
# test/8554.png
# test/8521.png
# test/8496.png
# test/8459.png
# test/8458.png
# test/8454.png
# test/8445.png
# test/8443.png
# test/8426.png
# test/8425.png
# test/8406.png
# test/8403.png
# test/8397.png
# test/8396.png
# test/8393.png
# test/8387.png
# test/8379.png
# test/8376.png
# test/8329.png
# test/8316.png
# test/8303.png
# test/8290.png
# test/8261.png
# test/8248.png
# test/8240.png
# test/8220.png
# test/8207.png
# test/8200.png
# test/8169.png
# test/8115.png
# test/8105.png
# test/8094.png
# test/8090.png
# test/8089.png
# test/8082.png
# test/8065.png
# test/8064.png
# test/8039.png
# test/8030.png
# test/8015.png
# test/8009.png
# test/7990.png
# test/7983.png
# test/7973.png
# test/7893.png
# test/7876.png
# test/7872.png
# test/7870.png
# test/7866.png
# test/7854.png
# test/7852.png
# test/7849.png
# test/7845.png
# test/7805.png
# test/7793.png
# test/7770.png
# test/7768.png
# test/7755.png
# test/7751.png
# test/7740.png
# test/7707.png
# test/7706.png
# test/7702.png
# test/7684.png
# test/7682.png
# test/7674.png
# test/7659.png
# test/7657.png
# test/7624.png
# test/7610.png
# test/7573.png
# test/7558.png
# test/7541.png
# test/7536.png
# test/7523.png
# test/7519.png
# test/7518.png
# test/7517.png
# test/7512.png
# test/7479.png
# test/10724.png
# test/10709.png
# test/10707.png
# test/10706.png
# test/10703.png
# test/10694.png
# test/10619.png
# test/10606.png
# test/10574.png
# test/10569.png
# test/10566.png
# test/10537.png
# test/10533.png
# test/10509.png
# test/10506.png
# test/10482.png
# test/10457.png
# test/10456.png
# test/10453.png
# test/10436.png
# test/10411.png
# test/10398.png
# test/10384.png
# test/10369.png
# test/10359.png
# test/10329.png
# test/10320.png
# test/10312.png
# test/10307.png
# test/10296.png
# test/10293.png
# test/10285.png
# test/10268.png
# test/10254.png
# test/10222.png
# test/10218.png
# test/10215.png
# test/10210.png
# test/10197.png
# test/10160.png
# test/10131.png
# test/10120.png
# test/10090.png
# test/10087.png
# test/10074.png
# test/10072.png
# test/10053.png
# test/10049.png
# test/10026.png
# test/9996.png
# test/9976.png
# test/9973.png
# test/9971.png
# test/9964.png
# test/9963.png
# test/9952.png
# test/9926.png
# test/9915.png
# test/9911.png
# test/9904.png
# test/9903.png
# test/9899.png
# test/9863.png
# test/9836.png
# test/9825.png
# test/9823.png
# test/9818.png
# test/9779.png
# test/9773.png
# test/9766.png
# test/9758.png
# test/9755.png
# test/9739.png
# test/9706.png
# test/9703.png
# test/9701.png
# test/9693.png
# test/9684.png
# test/9662.png
# test/9627.png
# test/9622.png
# test/9601.png
# test/9597.png
# test/9594.png
# test/9588.png
# test/9578.png
# test/9546.png
# test/9541.png
# test/9508.png
# test/9491.png
# test/9483.png
# test/9482.png
# test/9481.png
# test/9470.png
# test/9469.png
# test/9463.png
# test/9450.png
# test/9418.png
# test/9396.png
# test/9394.png
# test/9392.png
# test/9373.png
# test/9369.png
# test/9356.png
# test/9342.png
# test/9341.png
# test/9299.png
# test/9267.png
# test/9246.png
# test/9243.png
# test/9219.png
# test/9213.png
# test/9210.png
# test/9206.png
# test/9191.png
# test/9184.png
# test/9177.png
# test/9159.png
# test/9145.png
# test/9136.png
# test/9114.png
# test/9113.png
# test/9109.png
# test/9082.png
# test/9069.png
# test/9053.png
# test/9051.png
# test/9044.png
# test/12341.png
# test/12337.png
# test/12335.png
# test/12334.png
# test/12320.png
# test/12281.png
# test/12259.png
# test/12240.png
# test/12236.png
# test/12216.png
# test/12210.png
# test/12205.png
# test/12195.png
# test/12188.png
# test/12185.png
# test/12168.png
# test/12150.png
# test/12147.png
# test/12142.png
# test/12134.png
# test/12108.png
# test/12105.png
# test/12100.png
# test/12089.png
# test/12078.png
# test/12068.png
# test/12065.png
# test/12049.png
# test/12041.png
# test/12014.png
# test/12001.png
# test/11983.png
# test/11982.png
# test/11967.png
# test/11929.png
# test/11913.png
# test/11909.png
# test/11895.png
# test/11891.png
# test/11860.png
# test/11859.png
# test/11823.png
# test/11788.png
# test/11771.png
# test/11770.png
# test/11769.png
# test/11765.png
# test/11733.png
# test/11713.png
# test/11701.png
# test/11698.png
# test/11694.png
# test/11688.png
# test/11681.png
# test/11653.png
# test/11648.png
# test/11610.png
# test/11608.png
# test/11592.png
# test/11568.png
# test/11562.png
# test/11547.png
# test/11541.png
# test/11531.png
# test/11520.png
# test/11519.png
# test/11513.png
# test/11506.png
# test/11500.png
# test/11492.png
# test/11459.png
# test/11419.png
# test/11413.png
# test/11366.png
# test/11361.png
# test/11357.png
# test/11355.png
# test/11333.png
# test/11319.png
# test/11298.png
# test/11292.png
# test/11287.png
# test/11284.png
# test/11280.png
# test/11236.png
# test/11231.png
# test/11214.png
# test/11205.png
# test/11197.png
# test/11195.png
# test/11179.png
# test/11173.png
# test/11146.png
# test/11134.png
# test/11127.png
# test/11091.png
# test/11072.png
# test/11065.png
# test/11063.png
# test/11027.png
# test/11026.png
# test/11007.png
# test/11004.png
# test/10993.png
# test/10991.png
# test/10978.png
# test/10954.png
# test/10947.png
# test/10923.png
# test/10921.png
# test/10915.png
# test/10911.png
# test/10906.png
# test/10884.png
# test/10873.png
# test/10872.png
# test/10841.png
# test/10839.png
# test/10833.png
# test/10813.png
# test/10799.png
# test/10791.png
# test/10788.png
# test/10779.png
# test/10775.png
# test/10749.png
# test/10737.png
# test/10736.png
# test/10297.png
# test/9975.png
# test/9537.png
# test/9466.png
# test/9377.png
# test/9279.png
# test/9153.png
# test/9112.png
# test/9072.png
# test/8648.png
# test/8600.png
# test/8405.png
# test/8181.png
# test/8074.png
# test/8053.png
# test/7967.png
# test/7570.png
# test/7407.png
# test/7255.png
# test/7127.png
# test/6906.png
# test/6806.png
# test/6319.png
# test/6207.png
# test/6106.png
# test/6085.png
# test/5774.png
# test/5764.png
# test/5591.png
# test/5536.png
# test/5260.png
# test/5240.png
# test/4985.png
# test/4535.png
# test/4491.png
# test/4458.png
# test/4383.png
# test/4357.png
# test/4349.png
# test/4011.png
# test/3852.png
# test/3777.png
# test/3531.png
# test/3454.png
# test/2538.png
# test/2425.png
# test/1942.png
# test/896.png
# test/825.png
# test/626.png
# test/519.png
# test/456.png
# test/374.png
# test/234.png
# test/133.png
# test/12.png
# test/13058.png
# test/13050.png
# test/13027.png
# test/13025.png
# test/12998.png
# test/12959.png
# test/12950.png
# test/12935.png
# test/12922.png
# test/12913.png
# test/12897.png
# test/12881.png
# test/12873.png
# test/12872.png
# test/12871.png
# test/12857.png
# test/12849.png
# test/12832.png
# test/12830.png
# test/12829.png
# test/12821.png
# test/12803.png
# test/12762.png
# test/12739.png
# test/12725.png
# test/12718.png
# test/12711.png
# test/12705.png
# test/12698.png
# test/12696.png
# test/12692.png
# test/12690.png
# test/12689.png
# test/12670.png
# test/12666.png
# test/12664.png
# test/12659.png
# test/12649.png
# test/12639.png
# test/12632.png
# test/12625.png
# test/12619.png
# test/12612.png
# test/12603.png
# test/12593.png
# test/12585.png
# test/12583.png
# test/12578.png
# test/12577.png
# test/12549.png
# test/12542.png
# test/12541.png
# test/12532.png
# test/12523.png
# test/12520.png
# test/12517.png
# test/12509.png
# test/12505.png
# test/12496.png
# test/12489.png
# test/12488.png
# test/12486.png
# test/12485.png
# test/12471.png
# test/12447.png
# test/12413.png
# test/12402.png
# test/12393.png
# test/12368.png
# test/12364.png
# test/12360.png
# test/12350.png
# test/12808.png
# test/12770.png
# test/12352.png
# test/12242.png
# test/12115.png
# test/12032.png
# test/11785.png
# test/11703.png
# test/11662.png
# test/11642.png
# test/10986.png
# test/10780.png
# test/10671.png
# test/10549.png

# %% [markdown]
# Now we can look at the side bar and find our new test directory in the

# %%
from IPython.display import Image
Image('test/1.png')

# %%
# !pip install mat73
import mat73

data_dict = mat73.loadmat('test/digitStruct.mat')
# Out:
# Collecting mat73
#   Downloading mat73-0.62-py3-none-any.whl (19 kB)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from mat73) (3.9.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from mat73) (1.23.5)
# Installing collected packages: mat73
# Successfully installed mat73-0.62

# %% [markdown]
# Above we are pulling the MatLab formatted information about our images from the digitStruct.mat file and printed them out. We can find the 'label' entries which correspond to the image we pull up in this numpy array. This will take a few minutes.

# %%
print(data_dict)
# Out:
# {'digitStruct': {'bbox': [{'height': array(30.), 'label': array(5.), 'left': array(43.), 'top': array(7.), 'width': array(19.)}, {'height': [array(23.), array(23.), array(23.)], 'label': [array(2.), array(1.), array(10.)], 'left': [array(99.), array(114.), array(121.)], 'top': [array(5.), array(8.), array(6.)], 'width': [array(14.), array(8.), array(12.)]}, {'height': array(16.), 'label': array(6.), 'left': array(61.), 'top': array(6.), 'width': array(11.)}, {'height': array(17.), 'label': array(1.), 'left': array(32.), 'top': array(6.), 'width': array(14.)}, {'height': array(28.), 'label': array(9.), 'left': array(97.), 'top': array(28.), 'width': array(19.)}, {'height': array(23.), 'label': array(1.), 'left': array(40.), 'top': array(11.), 'width': array(7.)}, {'height': [array(21.), array(21.), array(21.)], 'label': [array(1.), array(8.), array(3.)], 'left': [array(44.), array(51.), array(62.)], 'top': [array(7.), array(6.), array(6.)], 'width': [array(9.), array(11.), array(10.)]}, {'height': [array(23.), array(23.)], 'label': [array(6.), array(5.)], 'left': [array(62.), array(80.)], 'top': [array(16.), array(17.)], 'width': [array(14.), array(14.)]}, {'height': [array(18.), array(18.), array(18.)], 'label': [array(1.), array(4.), array(4.)], 'left': [array(27.), array(40.), array(52.)], 'top': [array(8.), array(5.), array(7.)], 'width': [array(12.), array(13.), array(15.)]}, {'height': [array(21.), array(21.)], 'label': [array(1.), array(6.)], 'left': [array(16.), array(26.)], 'top': [array(19.), array(19.)], 'width': [array(7.), array(12.)]}, {'height': [array(43.), array(43.)], 'label': [array(3.), array(4.)], 'left': [array(52.), array(78.)], 'top': [array(9.), array(12.)], 'width': [array(24.), array(29.)]}, {'height': [array(16.), array(16.)], 'label': [array(2.), array(10.)], 'left': [array(27.), array(37.)], 'top': [array(12.), array(12.)], 'width': [array(10.), array(10.)]}, {'height': [array(23.), array(23.)], 'label': [array(1.), array(3.)], 'left': [array(157.), array(164.)], 'top': [array(106.), array(106.)], 'width': [array(9.), array(12.)]}, {'height': [array(24.), array(24.)], 'label': [array(2.), array(5.)], 'left': [array(64.), array(80.)], 'top': [array(27.), array(23.)], 'width': [array(13.), array(13.)]}, {'height': array(91.), 'label': array(4.), 'left': array(524.), 'top': array(235.), 'width': array(71.)}, {'height': [array(27.), array(27.)], 'label': [array(1.), array(4.)], 'left': [array(37.), array(46.)], 'top': [array(7.), array(8.)], 'width': [array(9.), array(16.)]}, {'height': [array(13.), array(13.)], 'label': [array(2.), array(8.)], 'left': [array(41.), array(54.)], 'top': [array(11.), array(12.)], 'width': [array(11.), array(6.)]}, {'height': [array(18.), array(18.)], 'label': [array(3.), array(8.)], 'left': [array(35.), array(49.)], 'top': [array(8.), array(7.)], 'width': [array(12.), array(12.)]}, {'height': [array(54.), array(54.)], 'label': [array(6.), array(10.)], 'left': [array(220.), array(253.)], 'top': [array(177.), array(167.)], 'width': [array(28.), array(31.)]}, {'height': [array(24.), array(24.), array(24.)], 'label': [array(1.), array(5.), array(1.)], 'left': [array(143.), array(156.), array(167.)], 'top': [array(17.), array(17.), array(20.)], 'width': [array(14.), array(14.), array(13.)]}, {'height': [array(20.), array(20.), array(20.)], 'label': [array(1.), array(2.), array(9.)], 'left': [array(63.), array(63.), array(65.)], 'top': [array(13.), array(32.), array(52.)], 'width': [array(9.), array(13.), array(14.)]}, {'height': [array(18.), array(18.)], 'label': [array(1.), array(6.)], 'left': [array(43.), array(50.)], 'top': [array(10.), array(10.)], 'width': [array(6.), array(10.)]}, {'height': array(22.), 'label': array(9.), 'left': array(73.), 'top': array(51.), 'width': array(18.)}, {'height': [array(32.), array(32.)], 'label': [array(2.), array(6.)], 'left': [array(36.), array(53.)], 'top': [array(3.), array(2.)], 'width': [array(11.), array(11.)]}, {'height': array(20. ...

# %% [markdown]
# ---
#
# ###Case Study

# %% [markdown]
# Now we are going to take a look at a practical example of manipulating datasets for use in ML/DL training. For this case study, we will be looking at both a water quality and a weather dataset. We will be picking out the data we want from each of the datasets and combining them into one using the data collection dates to combine these data points into one new coherant dataset. You could imagine how predicting water quality could be very important for general health, environmental studies, and companies that work in water processing.

# %% [markdown]
# This part of the workshop is essentially going to boil down to a crash course in Pandas which is a popular Python library for data analysis and manipulation. While I am going to be showing you some of the things you can do with Pandas, I would highly suggest you refer to the Pandas docs and tutorials (https://pandas.pydata.org/) before taking on your own project like this.

# %% [markdown]
# This dataset is for the City of Austin and can be found here: https://data.austintexas.gov/Environment/Water-Quality-Sampling-Data/5tye-7ray
# I went ahead and shortened the dataset considerable as it was quite large. Since this is just a demonstration we don't need the whole dataset and we won't have to wait a long time for Google Colab to download the dataset file. The weather dataset comes from NOAA and was retrieved using their climate data tool found in this link (https://www.ncdc.noaa.gov/cdo-web/). I hosted the datasets we will be using in a Github repository so we first need to clone that repo into our notebook. Then let's read in our CSV and take a look at our data.

# %%
# !git clone https://github.com/michaelabuchanan/datasets_workshop.git
# Out:
# Cloning into 'datasets_workshop'...
# remote: Enumerating objects: 4, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 4 (delta 0), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (4/4), 1.50 MiB | 3.42 MiB/s, done.

# %%
import pandas as pd

water_dataset = pd.read_csv('datasets_workshop/water_quality_short.csv')
print(len(water_dataset))
water_dataset
# Out:
# 50614
#        Unnamed: 0  DATA_REF_NO  DEPTH_IN_METERS  FILTER  LAT_DD_WGS84  \
# 0          224008      1738311              NaN   Total     30.264246
# 1          224009      1738310              NaN  Larvae     30.264246
# 2          224010      1738309              NaN  Larvae     30.264246
# 3          224011      1738306              NaN   Total     30.264246
# 4          224012      1738132              NaN   Total     30.264246
# ...           ...          ...              ...     ...           ...
# 50609     1377599      1768550              NaN   Total     30.286180
# 50610     1377600      1771728              NaN   Total     30.286180
# 50611     1377601      1771725              NaN   Total     30.286180
# 50612     1377602      1771724              NaN   Total     30.286180
# 50613     1377603      1771444              NaN   Total     30.286180
#
#        LON_DD_WGS84         MEDIUM             METHOD  \
# 0        -97.770061  Benthic Cover  VISUAL ASSESSMENT
# 1        -97.770061  Benthic Cover  VISUAL ASSESSMENT
# 2        -97.770061  Benthic Cover  VISUAL ASSESSMENT
# 3        -97.770061  Benthic Cover  VISUAL ASSESSMENT
# 4        -97.770061  Benthic Cover  VISUAL ASSESSMENT
# ...             ...            ...                ...
# 50609    -97.597247         Diatom            UNKNOWN
# 50610    -97.597247         Diatom            UNKNOWN
# 50611    -97.597247         Diatom            UNKNOWN
# 50612    -97.597247         Diatom            UNKNOWN
# 50613    -97.597247         Diatom            UNKNOWN
#
#                        PARAM_TYPE                         PARAMETER  ...  \
# 0      Benthic Macroinvertebrates  ANNELIDA (WORM/LEECHES/PLANARIA)  ...
# 1      Benthic Macroinvertebrates               DIPTERA (MIDGE/FLY)  ...
# 2      Benthic Macroinvertebrates           TRICHOPTERA (CADDISFLY)  ...
# 3      Benthic Macroinvertebrates       PSEPHENIDAE (WATER PENNIES)  ...
# 4      Benthic Macroinvertebrates               CRAYFISH (JUVENILE)  ...
# ...                           ...                               ...  ...
# 50609                 Chlorophyte                        COELASTRUM  ...
# 50610                 Chlorophyte                        COELASTRUM  ...
# 50611                 Chlorophyte                       SCENEDESMUS  ...
# 50612                 Chlorophyte                       SCENEDESMUS  ...
# 50613                 Chlorophyte             CRUCIGENIA TETRAPEDIA  ...
#
#       RESULT          SAMPLE_DATE                    SAMPLE_ID SAMPLE_REF_NO  \
# 0      1.000  2010-01-06 10:50:00                      Quad IV        346765
# 1      1.000  2010-01-06 10:50:00                      Quad IV        346765
# 2      0.000  2010-01-06 10:50:00                      Quad IV        346765
# 3      1.000  2010-01-06 10:50:00                      Quad IV        346765
# 4      2.000  2010-01-06 10:50:00                      Quad IV        346765
# ...      ...                  ...                          ...           ...
# 50609  1.000  2010-10-20 11:40:00  #4344 Lake Long at Dam 4344        355333
# 50610  2.703  2010-10-20 11:40:00  #4344 Lake Long at Dam 4344        355333
# 50611  1.000  2010-10-20 11:40:00  #4344 Lake Long at Dam 4344        355333
# 50612  2.703  2010-10-20 11:40:00  #4344 Lake Long at Dam 4344        355333
# 50613  5.000  2010-10-20 11:40:00  #4344 Lake Long at Dam 4344        355333
#
#        SAMPLE_SITE_NO               SITE_NAME SITE_TYPE  TIME_NULL  \
# 0                 428            Eliza Spring    Spring          N
# 1                 428            Eliza Spring    Spring          N
# 2                 428            Eliza Spring    Spring          N
# 3                 428            Eliza Spring    Spring          N
# 4                 428            Eliza Spring    Spring          N
# ...               ...                     ...       ...        ...
# 50609            4344  Lake Long @ Dam (LWL3)      Lake          N
# 50610            4344  Lake Long @ Dam (LWL3)      Lake          N
# 50611            4344  Lake Long @ Dam (LWL3)      Lake          N
# 50612            4344  Lake Long @ Dam (LWL3)      Lake          N
# 50613            4344  Lake Long @ Dam (LWL3)      Lake          N
#
#                                                   UNIT            WATERSHED
# 0                                  1=Present; 0=Absent         Barton Creek
# 1                                  1=Present; 0=Absent         Barton Creek
# 2                                  1=Present; 0=Absent         Barton Creek
# 3                                  1=Present; 0=Absent         Barton Creek
# 4      Relative Abundance (1): <20 (2): 21-50 (3): >50         Barton Creek
# ...                                                ...                  ...
# 50609                                            Count  Walter E. Long Lake
# 50610                                           Org/mL  Walter E. Long Lake
# 50611                                            Count  Walter E. Long Lake
# 50612                                           Org/mL  Walter E. Long Lake
# 50613                                            Count  Walter E. Long Lake
#
# [50614 rows x 24 columns]

# %% [markdown]
# We have a lot of information here at our disposal. Let's say we are only interested in the PH water quality data. Looking at our table, this would mean keeping only the rows that say "PH" in the "PARAMETER" column. Luckily this is fairly easy to do with Pandas.

# %%
ph_dataset = water_dataset.loc[water_dataset['PARAMETER'] == "PH"]
print(len(ph_dataset))
ph_dataset
# Out:
# 864
#        Unnamed: 0  DATA_REF_NO  DEPTH_IN_METERS FILTER  LAT_DD_WGS84  \
# 248        227450      1731150              NaN  Total     30.264007
# 302        227504      1730293              NaN  Total     30.263535
# 468        227670      1731092              NaN  Total     30.259493
# 501        227703      1730419              NaN  Total     30.263535
# 995        228197      1730808              NaN  Total     30.264246
# ...           ...          ...              ...    ...           ...
# 50534     1377370      1759707              4.0  Total     30.292153
# 50535     1377371      1759703              3.0  Total     30.292153
# 50536     1377372      1759699              2.0  Total     30.292153
# 50537     1377373      1759690              0.2  Total     30.292153
# 50580     1377570      1759695              1.0  Total     30.292153
#
#        LON_DD_WGS84         MEDIUM        METHOD              PARAM_TYPE  \
# 248      -97.769383   Ground Water  Quanta Probe  Alkalinity/Hardness/pH
# 302      -97.770980   Ground Water  Quanta Probe  Alkalinity/Hardness/pH
# 468      -97.823701   Ground Water  Quanta Probe  Alkalinity/Hardness/pH
# 501      -97.770980   Ground Water  Quanta Probe  Alkalinity/Hardness/pH
# 995      -97.770061   Ground Water  Quanta Probe  Alkalinity/Hardness/pH
# ...             ...            ...           ...                     ...
# 50534    -97.609229  Surface Water      HYDROLAB  Alkalinity/Hardness/pH
# 50535    -97.609229  Surface Water      HYDROLAB  Alkalinity/Hardness/pH
# 50536    -97.609229  Surface Water      HYDROLAB  Alkalinity/Hardness/pH
# 50537    -97.609229  Surface Water      HYDROLAB  Alkalinity/Hardness/pH
# 50580    -97.609229  Surface Water      HYDROLAB  Alkalinity/Hardness/pH
#
#       PARAMETER  ... RESULT          SAMPLE_DATE SAMPLE_ID SAMPLE_REF_NO  \
# 248          PH  ...   7.02  2010-03-24 09:45:00       NaN        347967
# 302          PH  ...   6.94  2010-04-07 09:15:00       NaN        348591
# 468          PH  ...   7.19  2010-03-10 08:55:00       NaN        348635
# 501          PH  ...   7.01  2010-03-24 10:00:00       NaN        347953
# 995          PH  ...   7.00  2010-03-24 10:15:00       NaN        347964
# ...         ...  ...    ...                  ...       ...           ...
# 50534        PH  ...   8.15  2010-10-20 11:05:00       NaN        353514
# 50535        PH  ...   8.24  2010-10-20 11:05:00       NaN        353513
# 50536        PH  ...   8.33  2010-10-20 11:05:00       NaN        353512
# 50537        PH  ...   8.40  2010-10-20 11:05:00       NaN        353510
# 50580        PH  ...   8.45  2010-10-20 11:05:00       NaN        353511
#
#        SAMPLE_SITE_NO                                 SITE_NAME SITE_TYPE  \
# 248               860       Barton Spring Pool @ Downstream Dam    Stream
# 302                35                             Barton Spring    Spring
# 468               160                           Backdoor Spring    Spring
# 501                35                             Barton Spring    Spring
# 995               428                              Eliza Spring    Spring
# ...               ...                                       ...       ...
# 50534            4346  Lake Long mid-lake of Western Arm (LWL5)      Lake
# 50535            4346  Lake Long mid-lake of Western Arm (LWL5)      Lake
# 50536            4346  Lake Long mid-lake of Western Arm (LWL5)      Lake
# 50537            4346  Lake Long mid-lake of Western Arm (LWL5)      Lake
# 50580            4346  Lake Long mid-lake of Western Arm (LWL5)      Lake
#
#        TIME_NULL            UNIT            WATERSHED
# 248            N  Standard units         Barton Creek
# 302            N  Standard units         Barton Creek
# 468            N  Standard units         Barton Creek
# 501            N  Standard units         Barton Creek
# 995            N  Standard units         Barton Creek
# ...          ...             ...                  ...
# 50534          N  Standard units  Walter E. Long Lake
# 50535          N  Standard units  Walter E. Long Lake
# 50536          N  Standard units  Walter E. Long Lake
# 50537          N  Standard units  Walter E. Long Lake
# 50580          N  Standard units  Walter E. Long Lake
#
# [864 rows x 24 columns]

# %% [markdown]
# Now let's say we decide the only columns of value to us for our experiment are the sample date, sample depth, and the PH values. We are going to "pop" these columns out of our PH dataset and merge them into a new dataset.

# %%
date = ph_dataset.pop("SAMPLE_DATE")
depth = ph_dataset.pop("DEPTH_IN_METERS")
ph = ph_dataset.pop("RESULT")

simpler_ph_dataset = pd.concat([date, depth, ph], axis=1)
print(len(simpler_ph_dataset))
simpler_ph_dataset
# Out:
# 864
#                SAMPLE_DATE  DEPTH_IN_METERS  RESULT
# 248    2010-03-24 09:45:00              NaN    7.02
# 302    2010-04-07 09:15:00              NaN    6.94
# 468    2010-03-10 08:55:00              NaN    7.19
# 501    2010-03-24 10:00:00              NaN    7.01
# 995    2010-03-24 10:15:00              NaN    7.00
# ...                    ...              ...     ...
# 50534  2010-10-20 11:05:00              4.0    8.15
# 50535  2010-10-20 11:05:00              3.0    8.24
# 50536  2010-10-20 11:05:00              2.0    8.33
# 50537  2010-10-20 11:05:00              0.2    8.40
# 50580  2010-10-20 11:05:00              1.0    8.45
#
# [864 rows x 3 columns]

# %% [markdown]
# From the table above we can see that some of the DEPTH_IN_METERS values are NaN, which stands for "not a number" and indicates that these datapoints are missing. Let's see how many NaN values we have to make a decision on how to handle this.

# %%
print(simpler_ph_dataset['DEPTH_IN_METERS'].isna().sum())
print(simpler_ph_dataset['SAMPLE_DATE'].isna().sum())
print(simpler_ph_dataset['RESULT'].isna().sum())
# Out:
# 650
# 0
# 0

# %% [markdown]
# For the sake of example, let's say that we don't really care about losing 650 rows in our dataset so we are going to remove all rows that have NaN in the DEPTH_IN_METERS column. However, in a real world situation this probably would not be acceptable. You want to be careful using this strategy if there are a lot of NaN values relative to your dataset size or if you are trying to do time-series based predictions. In this case the model may get confused in training if there are random gaps in datapoints. However we are going to assume that we would have plenty of data if we weren't using an already shortened version of the dataset to begin with and use this strategy.

# %%
depth_average = simpler_ph_dataset['DEPTH_IN_METERS'].mean()
print(depth_average)

simpler_ph_dataset = simpler_ph_dataset.fillna(depth_average)
simpler_ph_dataset
# Out:
# 4.830841121495327
#                SAMPLE_DATE  DEPTH_IN_METERS  RESULT
# 248    2010-03-24 09:45:00         4.830841    7.02
# 302    2010-04-07 09:15:00         4.830841    6.94
# 468    2010-03-10 08:55:00         4.830841    7.19
# 501    2010-03-24 10:00:00         4.830841    7.01
# 995    2010-03-24 10:15:00         4.830841    7.00
# ...                    ...              ...     ...
# 50534  2010-10-20 11:05:00         4.000000    8.15
# 50535  2010-10-20 11:05:00         3.000000    8.24
# 50536  2010-10-20 11:05:00         2.000000    8.33
# 50537  2010-10-20 11:05:00         0.200000    8.40
# 50580  2010-10-20 11:05:00         1.000000    8.45
#
# [864 rows x 3 columns]

# %% [markdown]
# Before we call our water quality portion of our dataset done, let's double check that there are no NaN values in our other two columns.

# %%
print(simpler_ph_dataset['SAMPLE_DATE'].isna().sum())
print(simpler_ph_dataset['RESULT'].isna().sum())
# Out:
# 0
# 0

# %% [markdown]
# Now let's load in our weather dataset for Austin Texas. It provides hourly datapoints for 2010.

# %%
weather_dataset = pd.read_csv('datasets_workshop/weather.csv')
weather_dataset
# Out:
#            STATION                                           NAME  \
# 0      USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
# 1      USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
# 2      USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
# 3      USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
# 4      USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US
# ...            ...                                            ...
# 17513  USW00013958                       AUSTIN CAMP MABRY, TX US
# 17514  USW00013958                       AUSTIN CAMP MABRY, TX US
# 17515  USW00013958                       AUSTIN CAMP MABRY, TX US
# 17516  USW00013958                       AUSTIN CAMP MABRY, TX US
# 17517  USW00013958                       AUSTIN CAMP MABRY, TX US
#
#                  DATE  HLY-DEWP-10PCTL  HLY-DEWP-90PCTL  HLY-DEWP-NORMAL  \
# 0      01-01T01:00:00             23.0             57.9             37.1
# 1      01-01T02:00:00             22.1             57.9             36.9
# 2      01-01T03:00:00             22.1             59.0             36.9
# 3      01-01T04:00:00             21.2             59.0             36.8
# 4      01-01T05:00:00             21.2             59.0             36.5
# ...               ...              ...              ...              ...
# 17513  12-31T19:00:00             21.9             59.0             38.0
# 17514  12-31T20:00:00             23.0             59.0             38.1
# 17515  12-31T21:00:00             23.0             59.0             38.3
# 17516  12-31T22:00:00             23.0             59.0             38.4
# 17517  12-31T23:00:00             23.0             59.0             38.3
#
#        HLY-HIDX-NORMAL  HLY-PRES-10PCTL  HLY-PRES-90PCTL  HLY-PRES-NORMAL  \
# 0                  NaN              1.0              1.0              1.0
# 1                  NaN              1.0              1.0              1.0
# 2                  NaN              1.0              1.0              1.0
# 3                  NaN              1.0              1.0              1.0
# 4                  NaN              1.0              1.0              1.0
# ...                ...              ...              ...              ...
# 17513             52.9              1.0              1.0              1.0
# 17514             51.4              1.0              1.0              1.0
# 17515             50.3              1.0              1.0              1.0
# 17516             49.3              1.0              1.0              1.0
# 17517             48.3              1.0              1.0              1.0
#
#        ...  HLY-TEMP-NORMAL  HLY-WCHL-NORMAL  HLY-WIND-1STDIR  \
# 0      ...             44.6              NaN              1.0
# 1      ...             44.1              NaN              1.0
# 2      ...             43.8              NaN              1.0
# 3      ...             43.5              NaN              1.0
# 4      ...             43.0              NaN              1.0
# ...    ...              ...              ...              ...
# 17513  ...             52.9             51.1              1.0
# 17514  ...             51.4             49.5              1.0
# 17515  ...             50.2             48.2              1.0
# 17516  ...             49.3             47.1              1.0
# 17517  ...             48.3             46.1              1.0
#
#        HLY-WIND-1STPCT  HLY-WIND-2NDDIR  HLY-WIND-2NDPCT  HLY-WIND-AVGSPD  \
# 0                241.0              5.0            126.0              5.6
# 1                234.0              5.0            119.0              5.4
# 2                235.0              5.0            128.0              5.5
# 3                215.0              5.0            124.0              5.5
# 4                246.0              5.0            112.0              5.5
# ...                ...              ...              ...              ...
# 17513            230.0              4.0            184.0              7.0
# 17514            237.0              4.0            171.0              6.9
# 17515            262.0              5.0            153.0              6.9
# 17516            259.0              5.0            157.0              6.7
# 17517            247.0              5.0            158.0              6.5
#
#        HLY-WIND-PCTCLM  HLY-WIND-VCTDIR  HLY-WIND-VCTSPD
# 0                383.0            350.0              1.6
# 1                372.0            346.0              1.6
# 2                358.0            342.0              1.8
# 3                385.0            349.0              1.8
# 4                371.0            348.0              2.0
# ...                ...              ...              ...
# 17513            102.0             31.0              2.4
# 17514            119.0             20.0              2.2
# 17515            134.0             18.0              2.2
# 17516            155.0             13.0              2.2
# 17517            171.0              8.0              2.2
#
# [17518 rows x 22 columns]

# %% [markdown]
# We are going to quickly repeat some similar steps we took with the water quality dataset. Let's say we only care about data points from the Austin Bergstrom International Airport and we only want to know about temperature and windspeed.

# %%
# Retain only data points from airport
weather_dataset = weather_dataset.loc[weather_dataset['NAME'] == "AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US"]

# pop off columns of interest
weather_date = weather_dataset.pop('DATE')
weather_temp = weather_dataset.pop('HLY-TEMP-NORMAL')
weather_wind = weather_dataset.pop('HLY-WIND-AVGSPD')

# merge columns into new dataframe
simpler_weather_dataset = pd.concat([weather_date, weather_temp, weather_wind], axis=1)

simpler_weather_dataset
# Out:
#                 DATE  HLY-TEMP-NORMAL  HLY-WIND-AVGSPD
# 0     01-01T01:00:00             44.6              5.6
# 1     01-01T02:00:00             44.1              5.4
# 2     01-01T03:00:00             43.8              5.5
# 3     01-01T04:00:00             43.5              5.5
# 4     01-01T05:00:00             43.0              5.5
# ...              ...              ...              ...
# 8754  12-31T19:00:00             51.1              6.3
# 8755  12-31T20:00:00             49.0              6.1
# 8756  12-31T21:00:00             47.9              6.1
# 8757  12-31T22:00:00             46.9              6.1
# 8758  12-31T23:00:00             46.2              6.2
#
# [8759 rows x 3 columns]

# %% [markdown]
# Now for the tricky part. We want to combine data from these two seperate datasets together using corresponding dates. Two problems are already pretty apparent.
#
# For one, the dates in these two dataset are represented in different formats. We will handle this by converting both to Datetime format which is a built-in date/time handling format in Python. Learn more about Datetime in Python's documentation (https://docs.python.org/3/library/datetime.html).
#
# Second, our weather data is provided in hourly increments while there is no standard time interval for the water quality dataset. In this kind of a situation you have to think about what level of data accuracy is acceptable for your project and develop a solution based around that. Let's assume having weather data from within an hour of the water quality samples is acceptable. In that case, we are going to round the date data points in our water quality dataset to the closest whole hour so it is possible to align them with our weather information.

# %% [markdown]
# Let's start by converting the dates in our weather dataset from strings to Datetime objects.

# %%
# import datetime library
import datetime as dt

# pop off DATE column from weather dataset
original_dates = simpler_weather_dataset.pop('DATE')
new_dates = []

# for each date, turn into Datetime object and append to new_dates list
for index, value in original_dates.items():
  datetime_object = value.replace("T", "-2010 ")
  datetime_object = dt.datetime.strptime(datetime_object, '%m-%d-%Y %H:%M:%S')
  new_dates.append(datetime_object)

# combine simpler_weather_dataset with our list of new Datetime objects
new_dates = pd.Series(new_dates)
simpler_weather_dataset = pd.concat([new_dates, simpler_weather_dataset], axis=1)
simpler_weather_dataset = simpler_weather_dataset.dropna()

# name columns
simpler_weather_dataset.columns = ['Timestamp', 'HLY-TEMP-NORMAL', 'HLY-WIND-AVGSPD']

simpler_weather_dataset
# Out:
#                Timestamp  HLY-TEMP-NORMAL  HLY-WIND-AVGSPD
# 0    2010-01-01 01:00:00             44.6              5.6
# 1    2010-01-01 02:00:00             44.1              5.4
# 2    2010-01-01 03:00:00             43.8              5.5
# 3    2010-01-01 04:00:00             43.5              5.5
# 4    2010-01-01 05:00:00             43.0              5.5
# ...                  ...              ...              ...
# 8754 2010-12-31 19:00:00             51.1              6.3
# 8755 2010-12-31 20:00:00             49.0              6.1
# 8756 2010-12-31 21:00:00             47.9              6.1
# 8757 2010-12-31 22:00:00             46.9              6.1
# 8758 2010-12-31 23:00:00             46.2              6.2
#
# [8538 rows x 3 columns]

# %% [markdown]
# Now let's do something similar for our water quality dataset. We will have to add in a rounding step after we convert our dates to Datetime objects so that we will be able to match them with our weather datapoints. To do this we will use `re`, Python's regular expression library, to grab the minute portion of our datetime and add an hour if we are rounding up or just set to 0 if we are rounding down. Remember that manipulating datasets in such a way is not going to be recommended in certain situations so it is important to think about the problem you are trying to solve and how changing the dataset can affect your ability to learn useful information from it.

# %%
import re

# get SAMPLE_DATE column and initialize list to put our datetimes in
ph_dates = simpler_ph_dataset.pop('SAMPLE_DATE')
ph_datetimes = []

# for each date, turn into Datetime object and append to new_dates list
for index, value in ph_dates.items():
  # use regex to get min value
  min = re.split('[:]', value)
  min = int(min[1])

  # if minutes is > 30, we add an hour to our datetime
  if min > 30:
    add_hour = dt.timedelta(hours=1)
    datetime_object = dt.datetime.strptime(value, '%Y-%m-%d %H:%M:%S')
    datetime_object = datetime_object + add_hour

  # if the minutes is less than 30
  else:
    datetime_object = dt.datetime.strptime(value, '%Y-%m-%d %H:%M:%S')

  # replace minutes section with 00
  datetime_object = datetime_object.replace(minute=0)

  # add our new datetimes to our list
  ph_datetimes.append(datetime_object)

# convert our list to a Pandas Series
datetime_series = pd.Series(ph_datetimes, name="Timestamp")

# reset indexes so everything lines up when we combine these
simpler_ph_dataset = simpler_ph_dataset.reset_index(drop=True)
datetime_series = datetime_series.reset_index(drop=True)

# combine our datetime series with the rest of our dataset
simpler_ph_dataset = pd.concat([datetime_series, simpler_ph_dataset], ignore_index=True, axis=1)

# assign column names
simpler_ph_dataset.columns = ['Timestamp', 'DEPTH_IN_METERS', 'PH_RESULT']

simpler_ph_dataset
# Out:
#               Timestamp  DEPTH_IN_METERS  PH_RESULT
# 0   2010-03-24 10:00:00         4.830841       7.02
# 1   2010-04-07 09:00:00         4.830841       6.94
# 2   2010-03-10 09:00:00         4.830841       7.19
# 3   2010-03-24 10:00:00         4.830841       7.01
# 4   2010-03-24 10:00:00         4.830841       7.00
# ..                  ...              ...        ...
# 859 2010-10-20 11:00:00         4.000000       8.15
# 860 2010-10-20 11:00:00         3.000000       8.24
# 861 2010-10-20 11:00:00         2.000000       8.33
# 862 2010-10-20 11:00:00         0.200000       8.40
# 863 2010-10-20 11:00:00         1.000000       8.45
#
# [864 rows x 3 columns]

# %% [markdown]
# Now we are ready to combine our datapoints from our two datasets. This is where all our work converting our times to Datetimes is going to pay off. We can easily sort our dataset by date in ascending order with just one command. Then we just use the Pandas merge command while specifying that we want to `merge` on the Timestamp columns and we get the results we are looking for.

# %%
# sort by timestamp in ascending order
simpler_ph_dataset = simpler_ph_dataset.sort_values(by='Timestamp')
simpler_ph_dataset

# merge our two datasets using the Timestamp column
final_dataset = pd.merge(simpler_ph_dataset, simpler_weather_dataset, left_on=['Timestamp'], right_on=['Timestamp'])

final_dataset
# Out:
#               Timestamp  DEPTH_IN_METERS  PH_RESULT  HLY-TEMP-NORMAL  \
# 0   2010-01-06 15:00:00         4.830841       7.07             59.6
# 1   2010-01-06 15:00:00         4.830841       7.12             59.6
# 2   2010-01-06 15:00:00         4.830841       7.08             59.6
# 3   2010-01-06 16:00:00         4.830841       7.09             59.5
# 4   2010-01-21 10:00:00         4.830841       6.80             50.0
# ..                  ...              ...        ...              ...
# 856 2010-11-17 11:00:00         3.000000       7.75             64.5
# 857 2010-11-17 11:00:00         5.000000       7.61             64.5
# 858 2010-11-23 10:00:00         4.830841       7.41             59.2
# 859 2010-11-23 10:00:00         4.830841       7.74             59.2
# 860 2010-11-23 11:00:00         4.830841       7.73             62.4
#
#      HLY-WIND-AVGSPD
# 0               10.7
# 1               10.7
# 2               10.7
# 3               10.5
# 4                8.4
# ..               ...
# 856              9.6
# 857              9.6
# 858              8.9
# 859              8.9
# 860             10.1
#
# [861 rows x 5 columns]

# %% [markdown]
# This is where I will leave it for this example but as an exercise you could pull out the datapoints from a specific DEPTH_IN_METERS value. I would highly recommend that you pull up the original versions of your dataset and check them against the values in this table after performing a lot of operations on your dataset as we did here. This will help you catch any mistakes you made through this process and verify that the dataset is in good shape to use in training.

# %% [markdown]
# ---
#
# ###Useful Resources

# %% [markdown]
# Here are some links to some other useful websites and search engines to visit when looking for a dataset. A lot of these came from a great blog post linked [here](https://imerit.net/blog/the-60-best-free-datasets-for-machine-learning-all-pbm/) which I would recommend giving a read.

# %% [markdown]
# *   UCI Machine Learning Repository: https://archive.ics.uci.edu/ml/index.php
# *   Google Dataset Search: https://datasetsearch.research.google.com/
# *   AWS Open Data Registry: https://registry.opendata.aws/
# *   Wikipedia ML Datasets: https://en.wikipedia.org/wiki/List_of_datasets_for_machine-learning_research
